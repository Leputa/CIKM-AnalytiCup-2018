# %%
import pickle

# %%
with open('token_train.pkl', 'rb') as pkl:
    _, _, left, right, label = pickle.load(pkl)

# %%
cnt = 0 
max_length = 0
avg = 0

for i in range(len(left)):
    avg += len(left[i])
    if len(left[i]) > max_length:
        max_length = len(left[i])
    if len(left[i]) > 50:
        cnt += 1

for i in range(len(right)):
    avg += len(right[i])
    if len(right[i]) > max_length:
        max_length = len(right[i])
    if len(right[i]) > 50:
        cnt += 1
        
print(max_length)
print(cnt)
print(avg/(len(left) + len(right)))
# Out:
# 32
# 0
# 5.1064

# %%
with open('token_dev.pkl', 'rb') as pkl:
    _, _, left_dev, right_dev, label_dev = pickle.load(pkl)

# %%
cnt = 0 
max_length = 0
avg = 0

for i in range(len(left_dev)):
    avg += len(left_dev[i])
    if len(left_dev[i]) > max_length:
        max_length = len(left_dev[i])
    if len(left_dev[i]) > 50:
        cnt += 1

for i in range(len(right_dev)):
    avg += len(right_dev[i])
    if len(right_dev[i]) > max_length:
        max_length = len(right_dev[i])
    if len(right_dev[i]) > 50:
        cnt += 1

print(max_length)
print(cnt)
print(avg/(len(left_dev) + len(right_dev)))
# Out:
# 27
# 0
# 5.651785714285714

# %%
for i in range(200):
    print(str(left[i]) + "   " + str(right[i]))
# Out:
# ['hola', 'hago', 'clic', 'producto', 'recibido']   ['compré', 'producto', 'recibido', 'correo', 'electrónico', 'confirmación']
# ['¡', 'hola', 'cerré', 'disputa', '21', 'mayo', '2017', 'dice', 'realizará', 'reembolso', '¿', 'cuándo', 'reembolsará', 'dinero']   ['obtuve', 'reembolso', 'dinero', 'pasado', 'dos', 'meses', '¿', 'cuándo', 'devolverá', 'dinero']
# ['ordené', 'españa', 'españa', 'ahora', 'mandan', 'pedido', 'china']   ['pedido', 'llegó', 'color', 'diferente', 'pedí']
# ['¿', 'debo', 'pagar', 'impuestos', 'personalizados']   ['cómo', 'pagar', 'derechos', 'aduana']
# ['recibí', 'pedido']   ['pedido', 'muestra', 'pagado', 'hice']
# ['hola', 'eva', 'principio', 'pregunta', '¿', 'puedo', 'escribir', 'alemán']   ['¿', 'cómo', 'puedo', 'escribir', 'comentarios', 'productos']
# ['tan', 'enojado']   ['abrí', 'disputa', 'ahora']
# ['puedo', 'abrir', 'disputa']   ['puedo', 'rastrear']
# ['¿', 'cómo', 'puedo', 'verificar', 'número', 'pedido']   ['¿', 'dónde', 'puedo', 'ver', 'número', 'rastreador', 'pedidos']
# ['necesito', 'respuesta']   ['necesito', 'factura', 'artículo', 'compré']
# ['cómo', 'responder', 'disputa']   ['¿', 'cómo', 'respondo', 'comentarios']
# ['vivo', 'china', 'vivo', 'brasil']   ['quiero', 'contacto', 'vivo', 'ahora']
# ['¿', 'qué', 'significa:', 'orden', 'será', 'cerrada']   ['orden', 'seguimiento', 'qué', 'significa', 'colección']
# ['cómo', 'intercambiar', 'monedas']   ['¿', 'cómo', 'cambiar', 'monedas', 'cupón']
# ['¿', 'cómo', 'informo', 'vendedor', 'fraude']   ['quiero', 'informar', 'vendedor']
# ['hola', 'quiero', 'comprar', 'vendedor', 'ajustar', 'precio', 'sistema', 'funciona', 'automáticamente', 'permite', 'vendedor', 'ajuste', 'favor', 'ayuda']   ['hola', 'necesito', 'decirte', 'orden']
# ['¿', 'cómo', 'puedo', 'saber', 'si', 'pedido', 'sido', 'enviado']   ['¿', 'cómo', 'puedo', 'saber', 'si', 'pedido', 'enviado']
# ['cancelé', 'pedido', 'vendedor']   ['pagué', 'pedido']
# ['ordené', 'españa', 'españa', 'ahora', 'mandan', 'pedido', 'china']   ['proveedor', 'china']
# ['quiero', 'hacer', 'compras', 'cómo', 'comprar']   ['vendré', 'verte', 'mañana']
# ['hola', 'vivo', 'canadá', 'actualmente', 'rastreando', 'paquete', 'dice', 'llegado', 'país', 'destino', 'dice', 'está', 'estambul', '¿', 'paquete', 'enviado', 'país', 'equivocado']   ['¿', 'cuándo', 'puedo', 'recibir', 'paquete', 'después', 'enviar', 'producto']
# ['promoción', 'comenzó', '¿', 'qué', 'precio', 'producto', 'cambió']   ['¿', 'qué', 'precio', 'promoción', 'cambia']
# ['número', 'color', 'l']   ['¿', 'cómo', 'puedo', 'ver', 'mensaje']
# ['hecho', 'seguimiento']   ['disputa', 'compañía', 'hecho', 'resolver', 'problema']
# ['formularios', 'documentos', 'van']   ['¿', 'cuándo', 'recibiré', 'pedidos']
# ['cómo', 'hacer', 'pedido']   ['¿', 'cómo', 'hago', 'pedido']
# ['imposible', 'unirse', 'atención', 'cliente', 'contacto']   ['¿', 'cómo', 'puedo', 'contactar', 'servicio', 'atención', 'cliente']
# ['quiero', 'hacer', 'compras', 'cómo', 'comprar']   ['¿', 'qué', 'carrito', 'compras']
# ['puedo', 'abrir', 'disputa']   ['puedo', 'adjuntar', 'foto', 'disputa']
# ['pedido', 'está', 'siendo', 'procesado']   ['tarjeta', 'débito', 'está', 'siendo', 'aceptada']
# ['favor', 'plazo', 'protección', 'compra', 'terminado', '¿', 'puede', 'devolver', 'dinero', '¿', 'esperar', 'disputa', 'error', 'enviar', 'sitio', 'mercancía', 'enviada', 'brasil', 'gracias']   ['¿', 'cómo', 'devuelves', 'dinero', 'si', 'bienes', 'reciben']
# ['iniciado', 'sesión', 'sesión', 'anterior', 'expirado', 'favor', 'inicia', 'sesión', 'nuevo']   ['¿', 'qué', 'dice', 'proveedor', 'enviado', 'mensaje', 'pedido']
# ['sitio', 'seguro']   ['proveedor', 'desaparecido', 'sitio']
# ['acabo', 'recibir', 'correo', 'electrónico', 'dice', 'devolver', 'batería', 'pagar', 'franqueo', 'devolución', 'obtener', 'reembolso', 'culpa', 'recibir', 'artículo', 'incorrecto', 'vendedor', 'debe', 'enviarme', 'mensaje', 'vuelta']   ['recibí', 'correo', 'electrónico', 'diciendo', 'mensaje', 'pedido', 'ninguno']
# ['ok', 'favor', 'contáctame', 'personas']   ['¿', 'puedo', 'contactar', 'compradores']
# ['cómo', 'eliminar', 'mensajes', 'aplicación']   ['¿', 'cómo', 'eliminar', 'cookies']
# ['cancelar', 'orden']   ['vendedor', 'cancelará', 'pedido']
# ['querida', 'pagar', 'gran', 'cantidad', 'comentarios', 'adecuados']   ['¿', 'cómo', 'consulto', 'vendedor', 'si', 'comentarios']
# ['pasado', '32', 'días', 'veo', 'ninguna', 'actualización', 'pedido']   ['¿', 'qué', 'veo', 'ningún', 'registro', 'pedido']
# ['¿', 'cómo', 'extiendo', 'protección', 'comprador']   ['¿', 'cómo', 'puedo', 'ser', 'elegible', 'protección', 'comprador']
# ['hola', 'gustaría', 'saber', 'si', 'vendedor', 'necesita', 'envíe', 'vuelta', '¿', 'cómo', 'reembolsa', 'tarifas', 'envío', 'más', 'costo', 'vestido', 'usando', 'correo', 'registrado', 'singapur']   ['caro', 'mí', 'enviar', 'bien', 'vuelta']
# ['¿', 'cómo', 'hago', 'pedido']   ['¿', 'cómo', 'realizo', 'seguimiento', 'pedido']
# ['podría', 'ayudarme']   ['háblame']
# ['nunca', 'comprado']   ['compré', 'producto', 'recibido', 'correo', 'electrónico', 'confirmación']
# ['cómo', 'subir', 'foto']   ['puedo', 'subir', 'documentos']
# ['quiero', 'zapatos', 'más', 'anchos', 'caminar', 'ancho', 'debe', 'ser', 'ee', 'eee', 'eeee']   ['quiero', 'ser', 'cancelado', 'correos', 'electrónicos']
# ['toma', 'demasiado', 'tiempo']   ['cuánto', 'tiempo', 'tardará', 'envío']
# ['puedo', 'pagar', 'transferencia', 'bancaria']   ['tratando', 'hacer', 'pago', 'transferencia', 'bancaria', 'puedo']
# ['hola', 'dinero', 'quiero', 'hacer', 'hacer', 'hacer']   ['¿', 'qué', 'garantías', 'comprar', 'aquí']
# ['puse', 'autorización', 'aprobó', 'todavía', 'funciona']   ['cuándo', 'aprobará', 'reembolso', 'cuándo', 'recibiré']
# ['cómo', 'abrir', 'disputa', 'aplicación']   ['¿', 'cómo', 'puedo', 'abrir', 'disputa', 'si', 'orden', 'está', 'completa']
# ['favor', 'lea', 'arriba']   ['¿', 'cómo', 'puedo', 'leer', 'comentarios', 'escritos', 'mí']
# ['cómo', 'cancelar', 'disputa']   ['¿', 'cómo', 'cancelo', 'disputa']
# ['vendedor', 'anuncia', 'precio', 'incorrecto']   ['vendedor', 'enviado', 'mercancías', 'índice', 'incorrecto']
# ['recuperar', 'monedas', 'aplicación']   ['¿', 'cómo', 'recupero', 'pedido', 'eliminado', 'error']
# ['puedo', 'usar', 'cupón', 'u', 'obtener', 'descuento']   ['¿', 'cómo', 'puedo', 'obtener', 'descuento']
# ['necesito', 'encontrar', 'información', 'pago']   ['necesito', 'información', 'pago', 'western', 'union']
# ['recibí', 'reembolso']   ['¿', 'qué', 'recibí', 'reembolso']
# ['trato', 'reembolso', 'devuelvo', 'producto', 'menú', 'demasiado', 'caro', 'envío', 'productos', 'china', '¿', 'quién', 'soporta', 'costo', 'transporte', 'bienes']   ['¿', 'puedo', 'enviar', 'productos', 'china']
# ['quiero', 'ser', 'vendedor']   ['quiero', 'reembolso', 'completo', 'vendedor', 'estará', 'acuerdo']
# ['órdenes', 'llegaron', 'tiempo']   ['artículo', 'llegado']
# ['preocupación', 'conocer', 'progreso', 'pedido']   ['quiero', 'saber', 'cómo', 'pedido']
# ['cómo', 'configurar', 'moneda']   ['cómo', 'convertidor', 'moneda']
# ['quiero', 'dinero', 'tan', 'pronto', 'intente', 'nuevo', 'compre', 'usted']   ['¿', 'ofrecen', 'información', 'envío', 'si', 'compro', 'usted']
# ['hola', 'extendí', 'servicio', 'atención', 'cliente', '3', 'veces']   ['presioné', 'botón', 'pagar', 'ahora', '3', 'veces', '¿', 'puedo', 'hacer']
# ['razón', 'debe', 'razón', 'seguridad', 'suspendieron', 'cuenta']   ['cómo', 'verificar', 'motivo', 'disputa']
# ['cómo', 'eliminar', 'mensajes', 'aplicación']   ['cómo', 'eliminar', 'orden', 'paga']
# ['cómo', 'subir', 'evidencia', 'disputa']   ['sé', 'cómo', 'subir', 'fotos']
# ['¿', 'puedo', 'chatear', 'persona', 'robot', 'eva', 'está', 'entendiendo']   ['puedo', 'chatear', 'persona', 'real']
# ['necesito', 'cambio', 'puede', 'enviar', 'correo', 'electrónico', 'localizo', 'correo', 'electrónico', 'necesito', 'comprar']   ['necesito', 'dirección', 'correo', 'electrónico']
# ['¡', 'hola', 'buenas', 'noches', 'necesito', 'ayuda', 'puedo', 'emitir', 'ticket', 'pagar', 'cuenta']   ['necesito', 'ayuda', 'anna']
# ['favor', 'borre', 'cookies', 'navegador']   ['favor', 'dame', 'correo', 'electrónico', 'soporte', 'sitio']
# ['sé', 'problema']   ['sé', 'sitio', 'web']
# ['también']   ['tarifa', 'envío', 'demasiado', 'alta', 'mí']
# ['cómo', 'buscar', 'buen', 'vendedor']   ['¿', 'cómo', 'borrar', 'historial', 'búsqueda']
# ['pagado', 'producto']   ['pagado']
# ['cómo', 'vincular', 'tarjeta']   ['recibí', 'enlace', 'verificación', 'correo', 'electrónico']
# ['cómo', 'abrir', 'disputa']   ['¿', 'cómo', 'abrir', 'estuche']
# ['está', 'dando', 'respuesta', 'correcta:', 'necesito', 'diez', 'artículos', 'principales', 'vendí', '2017']   ['responderás']
# ['quiero', 'comprar', 'producto', 'sé', 'cómo', 'pagar', 'dinero']   ['quiero', 'pagarle', 'vendedor']
# ['cómo', 'dejar', 'comentarios', 'vendedor']   ['¿', 'cómo', 'dejar', 'comentario', 'anónimo']
# ['¿', 'cómo', 'veo', 'cupón']   ['¿', 'cómo', 'obtengo', 'cupón']
# ['paga', 'cancelada']   ['¿', 'cuándo', 'recibiré', 'reembolso', 'pedido', 'cancelado']
# ['presenté', 'apelación', 'hace', '4', 'días', 'ninguna', 'respuesta']   ['envié', 'dinero', 'hace', '3', 'días', 'cambió']
# ['cobraron', 'artículo', 'pensé', 'había', 'comprado', 'nunca', 'recibí', 'puedo', 'encontrar', 'rastro', 'pedidos']   ['nunca', 'recibido', 'producto', 'comprado']
# ['ordenado', 'dirección', 'correo', 'electrónico', 'incorrecta']   ['ingresado', 'dirección', 'entrega', 'incorrecta']
# ['quiero', 'cambiar', 'tamaño']   ['quiero', 'saber', 'tamaño', 'brasil']
# ['¿', 'cómo', 'puedo', 'informar', 'vendedor', 'fraude']   ['recibí', 'correo', 'electrónico', 'aviso', 'vendedor', 'sospechoso', 'problema', 'fraude']
# ['incapaz', 'encontrar', 'dirección']   ['incapaz', 'obtener', 'respuesta', 'vendedor']
# ['número', 'seguimiento', 'tratando', 'hacer', 'pedido']   ['tratando', 'ordenar', 'está', 'funcionando']
# ['si', 'pedido', 'muestra', "'pedido", "cancelado'", 'significa']   ['pagué', 'pedido', 'sigue', 'mostrando', 'mismo']
# ['leer', 'pregunta', 'responder', 'favor']   ['quiero', 'leer', 'comentarios', 'escritos', 'pedido']
# ['entonces', '¿', 'dónde', 'puedo', 'encontrar', 'cupones', 'intercambió', '¿', 'dónde', 'están']   ['puedo', 'ver', 'cupones']
# ['uso', 'cajero', 'automático']   ['si', 'quiero', 'usar', 'cupón']
# ['envío', 'rápido', 'mensajería']   ['hablas', 'rápido']
# ['cómo', 'encontrar', 'vendedor', 'confiable']   ['¿', 'puedo', 'encontrar', 'vendedor', 'verificado']
# ['alguien', 'más', 'sabe', 'vietnamita', 'quiero', 'oder']   ['quiero', 'saber', 'proceso', 'western', 'union', 'comprar']
# ['¿', 'cómo', 'uso', 'cupón', 'selecto']   ['¿', 'cómo', 'selecciono', 'moneda']
# ['necesito', 'hablar', 'ser', 'humano', 'favor']   ['quiero', 'hablar', 'humano', 'línea']
# ['cómo', 'hago', 'pedido']   ['¿', 'cómo', 'cancelo', 'pedido', 'congelado']
# ['hola', 'extendí', 'servicio', 'atención', 'cliente', '3', 'veces']   ['ahora', 'todavía', 'llegado', 'orden']
# ['puede', 'abrir', 'cuenta']   ['sentimos', 'cuenta', 'marcado', 'motivos', 'puede', 'participar', 'promoción']
# ['presento', 'apelación', 'pasa']   ['puedo', 'enviar', 'formulario', 'disputa']
# ['recibo', 'correo', 'electrónico', 'orden', 'protección', 'compras']   ['puedo', 'extender', 'tiempo', 'protección', 'orden']
# ['hora', 'china']   ['¿', 'qué', 'tiempo', 'procesamiento']
# ['necesito', 'confirmes', 'tarjeta', 'crédito']   ['guardé', 'tarjeta', 'crédito', 'necesito', 'reemplazarla', 'nueva']
# ['¿', 'número', 'teléfono']   ['numero', 'telefono']
# ['hola', 'contactar', 'ahora', 'había', 'icono', 'chat', 'ahora', 'lado', 'izquierdo', 'página', 'ahora', 'está']   ['hago', 'clic', 'pagar', 'ahora', 'está', 'llevando', 'página', 'inicio', 'sesión']
# ['tiempo', 'disputa', 'terminado']   ['tiempo', 'procesamiento', 'terminado', 'quiero', 'extenderlo']
# ['quiero', 'enviar', 'pedido', 'vez']   ['gustaría', 'pagar', 'artículo', 'vez']
# ['bien']   []
# ['devuélveme', 'operador']   ['cómo', 'convertir', 'cuenta', 'comprador', 'cuenta', 'vendedor']
# ['colega', 'dijo', 'sería', 'restaurado']   ['pagué', 'pedido', 'decía', 'todavía', 'está', 'esperando', 'pago']
# ['¿', 'jodida', 'computadora']   ['¿', 'persona', 'computadora']
# ['¿', 'cómo', 'puedo', 'verificar', 'si', 'vendedor', 'confiable']   ['¿', 'cómo', 'reviso', 'cupón']
# ['¿', 'contacta', 'vendedor']   ['puedo', 'contactar', 'vendedor']
# ['recibo', 'correo', 'electrónico', 'orden', 'protección', 'compras']   ['¿', 'puede', 'extender', 'protección', 'compra']
# ['después', 'hacer', 'pedido', 'dijeron', 'habría', 'envíos', 'adicionales', 'cambié', 'dirección', 'bueno', 'cambié', 'dirección', 'pagué', 'cargos', 'adicionales', 'ver', 'qué']   ['quiero', 'cambiar', 'dirección', 'envío', 'orden', 'logística']
# ['hola', 'podido', 'pagar', 'artículos', 'dice', 'error', 'intento', 'más', 'tarde', 'puedes', 'ayudar']   ['escrito', 'vendedor', 'diferentes', 'maneras', 'él', 'todavía', 'ignora']
# ['vendedor', 'cambió', 'método', 'envío']   ['¿', 'cómo', 'puedo', 'cambiar', 'método', 'envío']
# ['necesito', 'diez', 'mejores', 'artículos', 'vendieron', '2017', 'alta']   ['¿', 'qué', 'situación', 'será', 'reembolsado']
# ['quiero', 'confirmar', 'recibí', 'mercancía', 'contento', 'puedo', 'iniciar', 'sesión']   ['necesito', 'recibir', 'mercancía', 'pronto']
# ['entonces', 'comprando', 'caso']   ['quiero', 'extender', 'compra', 'protección']
# ['¿', 'puedo', 'ordenar', 'nombre', 'compañía']   ['nunca', 'ordenaré', 'compañía', 'vez']
# ['hola', 'quiero', 'enviar', 'correo', 'gerente', 'ventas', 'necesito', 'dirección', 'correo', 'electrónico']   ['necesito', 'dirección', 'correo', 'electrónico', 'empresa']
# ['si', 'producto', 'pedido', 'coloca', 'europa', 'quiero', 'llegar', 'finlandia', '¿', 'debo', 'pagar', 'impuestos']   ['quiero', 'hacer', 'pedido']
# ['problema', 'ustedes']   ['problema', 'pedido']
# ['cómo', 'cambiar', 'precio']   ['¿', 'cómo', 'sabes', 'precio']
# ['¿', 'qué', 'hora', 'debo', 'contactarlo', 'recibir', 'ayuda']   ['¿', 'qué', 'haces', 'tiempo', 'libre']
# ['¿', 'cómo', 'cancelo', 'cuenta']   ['gustaría', 'saber', 'cómo', 'cancelar', 'cuenta']
# ['así', 'favor', 'borra', 'nueva', 'cuenta']   ['quiero', 'reactivar', 'cuenta', 'favor', 'ayuda']
# ['qué', 'precio', 'producto', 'cambió']   ['¿', 'cómo', 'cambio', 'precio', 'euros']
# ['colega', 'dijo', 'sería', 'restaurado']   ['vendedor', 'dijo', 'bienes', 'perdieron']
# ['puedo', 'ver', 'orden', 'auto']   ['¿', 'qué', 'puedo', 'ver', 'comentarios']
# ['hola', 'pedí', 'disfraz', 'cosplay', 'moneda', 'equivocada', 'cancelé', 'pedido', 'vendedor', 'dijo', 'aclaró', 'inmediato', 'ahora', 'suficiente', 'crédito', 'tarjeta', '¿', 'podría', 'amablemente', 'recibir', 'cantidad', 'más', 'rápido', 'posible', 'volver']   ['vendedor', 'dijo', 'cancelara', 'orden', 'devolver', 'dinero', '¿', 'puedo', 'hacer']
# ['él', 'escribió', 'ayer']   ['vendedor', 'cambia', 'operador', 'avisarme', 'ahora', 'quiere', 'pague', 'cargos', 'adicionales']
# ['dirección', 'predeterminada']   ['¿', 'puede', 'vendedor', 'cambiar', 'dirección']
# ['hola', 'contactar', 'ahora', 'había', 'icono', 'chat', 'ahora', 'lado', 'izquierdo', 'página', 'ahora', 'está']   ['¿', 'cuál', 'momento']
# ['ser', 'humano']   ['necesito', 'hablar', 'humano']
# ['gustaría', 'más', 'pronto', 'posible']   ['gustaría', 'chatear', 'vivo']
# ['entonces', 'debe', 'ser', 'broma', 'debes', 'bromeando']   ['confundiste']
# ['pregunté', 'hablando', 'computadora', '¿']   ['disputa', 'progreso', 'vendedor', 'niega', 'hablar', 'conmigo']
# ['¿', 'puedo', 'reabrir', 'disputa']   ['¿', 'puedo', 'reabrir', 'disputa', 'después', 'cerrarla']
# ['hago', 'clic', 'botón', 'pagar', 'ahora', 'dice', 'cada', 'vez', 'errores', 'así', 'puedo', 'pagar', 'pedido']   ['devuelto', 'pedido', 'pedido', 'completado']
# ['cada', 'vez', 'intento', 'pagar', 'pedido', 'realizado', 'aparece', 'mensaje', 'error', 'indica', '"motivos', 'seguridad"', 'pudo', 'ejecutar', 'pago', '¿', 'cómo', 'puede', 'resolver']   ['recibí', 'correo', 'electrónico', 'decía', 'orden', 'cancelada', 'falta', 'pago']
# ['qué', 'precio', 'producto', 'cambió']   ['proveedor', 'cambia', 'precio', 'orden', 'permiso']
# ['retroalimentación', 'muestra']   ['cuenta', 'aparece', 'español', 'necesito', 'inglés']
# ['acuerdo', 'favor', 'puedo', 'preguntarle']   ['puedo', 'preguntarte']
# ['solo', 'necesito', 'reembolso', 'feliz', 'favor', 'pague', 'dinero']   ['necesito', 'representante', 'vivo', 'favor']
# ['hola', 'gustaría', 'saber', 'cómo', 'patrocinar', 'amigo']   ['gustaría', 'saber', 'comentarios', 'vendedor']
# ['cancelado', 'envío']   ['información', 'envío', 'momento']
# ['ven', 'cama']   ['quiero', 'paquete', 'llegue', 'más', 'rápido']
# ['correo', 'electrónico', 'registro', 'funciona']   ['recibí', 'correo', 'electrónico', 'registro', 'pude', 'ver', 'enlace', 'verificación', 'hacer', 'clic', 'él']
# ['recibo', 'pedido']   ['hables', 'ingles']
# ['¿', 'puedo', 'usar', 'tarjeta', 'visa', 'entonces', 'si', 'así', '¿', 'cómo', 'podría', 'agregar', 'tarjeta', 'información']   ['¿', 'cómo', 'puedo', 'comprar', 'productos', 'si', 'tarjeta', 'visa']
# ['cómo', 'pago', 'dinero', 'producto', 'elijo']   ['¿', 'cómo', 'elijo', 'colores', 'quiero']
# ['quiero', 'usar', 'método', 'pago']   ['quiero', 'cancelar', 'pedido', 'usar', 'dinero', 'pagar', 'pedido']
# ['hola', 'eva', 'necesito', 'eliminar', 'tarjeta', 'crédito', 'anterior', 'registrar', 'nueva', 'tarjeta', 'crédito']   ['quiero', 'reembolso', 'tarjeta', 'crédito']
# ['gustaría', 'saber', 'arancel', 'adicional', '¿', 'qué', '¿', 'cómo', 'puedo', 'usar']   ['recibí', 'cupón', 'descuento', 'gustaría', 'saber', 'cómo', 'puedo', 'usarlo']
# ['recibido', 'bienes']   ['¿', 'cómo', 'presento', 'disputa', 'después', 'recibir', 'bienes', 'tiempo', 'agotó']
# ['pregunta', 'anterior']   ['pregunta', 'reembolso']
# ['recibí', 'pedidos', 'descontento', 'forma', 'huelen', 'zapatos']   ['recibí', 'artículo', 'mal']
# ['último', 'comandante', 'compro']   ['¿', 'qué', 'puedo', 'comprar', 'productos', 'cuenta']
# ['analizado', 'sugirió', 'ayudó', 'necesito', 'cuenta', 'eliminada', 'contraseña', 'restablecer', 'correo', 'electrónico', 'nombre', 'usuario', 'favor', 'pon', 'jefe']   ['hice', 'pago', 'línea', 'pago', 'realizó']
# ['cómo', 'aplicar', 'garantía']   ['¿', 'cupón', 'aplica', 'automáticamente']
# ['pagué', 'productos', 'nunca', 'recibido', 'embargo', 'puesto', 'confirmación', 'recibo', 'también', 'comentario']   ['nunca', 'recibido', 'producto', 'comprado']
# ['pedido', 'sido', 'enviado', 'hace', '20', 'días', 'aún', 'recibí']   ['¿', 'cómo', 'sé', 'si', 'pedido', 'sido', 'enviado']
# ['sentimos', 'transacción', 'pasó', 'verificación', 'debido', 'razones', 'seguridad', 'transacción', 'sido', 'cerrada']   ['siento', 'pago', 'exitoso', 'deducido', 'dinero']
# ['puedo', 'abrir', 'disputa']   ['¿', 'puedo', 'abrir', 'disputa', 'cancelé']
# ['ok', 'pierdes']   ['perdí', 'contraseña']
# ['quiero', 'cambiar', 'tarjeta', 'crédito', 'está', 'registrada', 'pago']   ['quiero', 'reembolso', 'tarjeta', 'crédito']
# ['¿', 'cómo', 'puedo', 'cambiar', 'datos', 'tarjeta', 'crédito']   ['¿', 'cómo', 'puedo', 'cambiar', 'dirección', 'envío']
# ['¿', 'qué', 'pasará', 'abra', 'disputa']   ['¿', 'cuándo', 'recibiré', 'reembolso', 'después', 'abrir', 'disputa']
# ['puedo', 'hablar', 'vivo']   ['puedo', 'hablar', 'inglés']
# ['cómo', 'encontrar', 'vendedor', 'confiable']   ['¿', 'cómo', 'encuentro', 'vendedores', 'confiables']
# ['hora', 'china']   ['¿', 'cuál', 'número', 'contacto', 'china', 'post']
# ['quiero', 'robot', 'estúpido', 'necesito', 'respuesta']   ['hablo', 'ingles', 'bien']
# ['compré', 'iteam', 'ayer', 'cobrado', 'iteam', 'aparece', 'extracto', 'tarjeta', 'crédito', 'trato', 'averiguar', 'qué', 'ingreso', 'historial', 'compras', 'aparece', 'número', 'pedido', 'número', 'seguimiento']   ['¿', 'cómo', 'puedo', 'encontrar', 'número', 'rastreo']
# ['¿', 'qué', 'protección', 'comprador']   ['protección', 'comprador']
# ['¿', 'qué', 'sigues', 'publicándome', '¡', '¡', '¡', 'caliente', 'encendedor', 'cigarrillos', 'llama', 'recargable', 'usb', 'electrónico', 'gadgets', 'gas', 'color', 'blanco"', 'etc', 'dicen', '"no', 'puede', 'entregar', 'finlandia"', '¿', 'qué', 'puede', 'enviar', 'finlandia']   ['¿', 'cuántos', 'días', 'entregar', 'paquete']
# ['cómo', 'usar', 'servicio', 'garantía']   ['cómo', 'usar', 'cupón']
# ['vendedor', 'comportamiento']   ['problema', 'vendedor', 'malo']
# ['hago', 'puedo']   ['puedo', 'hablar', 'inglés']
# ['¿', 'creé', 'cuenta', 'pedí', 'producto']   ['qué', 'puedo', 'crear', 'cuenta', 'mí']
# ['¿', 'qué', 'sucede', 'pedido', 'envío', 'indica', '"envío', 'cancelado"']   ['¿', 'qué', 'sucede', 'si', 'pedido', 'muestra', 'dos', 'veces', 'cuenta']
# ['¿', 'cómo', 'puedo', 'volver', 'enviar', 'vendedor', 'fraude']   ['¿', 'cómo', 'puedo', 'cambiar', 'disputa', 'si', 'vendedor', 'está', 'acuerdo']
# ['cargador', 'inalámbrico', 'recibí', 'está', 'defectuoso', 'carga']   ['productos', 'defectuosos']
# ['¿', 'puedes', 'bailar', 'mí']   ['puedes', 'llamarme']
# ['hola', 'eva', 'principio', 'pregunta', '¿', 'puedo', 'escribir', 'alemán']   ['eva', 'entendiste', 'pregunta']
# ['cómo', 'eliminar', 'tarjeta', 'crédito']   ['¿', 'cómo', 'eliminar', 'pedidos', 'innecesarios']
# ['¿', 'puedo', 'cambiar', 'cantidad', 'variantes', 'producto', 'poder', 'importarlo', 'shopify']   ['¿', 'puedo', 'importar', '1', 'solo', 'artículo']
# ['¿', 'cómo', 'obtengo', 'cupones', 'descuentos']   ['¿', 'puedo', 'obtener', 'cupones', 'reactivados']
# ['hace', 'par', 'semanas', 'busqué', 'camisetas', 'nasa', 'tienda', 'aquel', 'entonces', 'tenía', 'resultados', 'ahora', 'resultados', '¿', 'cómo', 'puedo', 'encontrar', 'productos', 'nuevamente']   ['¿', 'cómo', 'estrechar', 'resultados', 'búsqueda']
# ['hola', 'vencimiento', 'tarjeta', 'crédito', 'expirado', 'puedo', 'encontrar', 'ningún', 'lugar', 'puedan', 'sobrescribir', 'nuevos', 'datos', 'tarjeta', '¿', 'usted', 'podría', 'ayudar']   ['puedo', 'usar', 'tarjeta', 'credito']
# ['guardar', 'más', 'adelante']   ['¿', 'qué', 'hacer', 'si', 'pedido', 'pagó', 'luego', 'cerró']
# ['favor', 'lea', 'arriba']   ['favor', 'lee', 'pregunta']
# ['¿', 'puedes', 'leer']   ['favor', 'lee', 'pregunta']
# ['¿', 'puedo', 'hacer', 'pregunta']   ['quiero', 'hacer', 'pregunta']
# ['nombre', 'bill']   ['eliminar', 'nombre', 'transacción']
# ['favor', 'alguien', 'sepa', 'español', 'resulta', 'difícil', 'escribir', 'traducir', 'luego', 'traducir', 'escribe']   ['favor', 'dime', 'paso', 'articulos']

# %%
with open('all_token.pkl', 'rb') as pkl:
    es = pickle.load(pkl)[0]

# %%
len(es)
# Out:
# 108469

# %%
with open('translation_token.pkl', 'rb') as pkl:
    es,en = pickle.load(pkl)

# %%
es
# Out:
# [['qué',
#   'podido',
#   'procesar',
#   'pago',
#   'razones',
#   'seguridad',
#   'si',
#   'pedido',
#   'está',
#   'cerrado',
#   'razones',
#   'seguridad',
#   'aún',
#   'cobra',
#   'pago'],
#  ['duda', 'pregunta', 'cupones'],
#  ['favor',
#   'necesito',
#   'saber',
#   'si',
#   'compra',
#   'todavía',
#   'va',
#   'llegar',
#   'fiz',
#   'abril',
#   'ahora',
#   'llegó',
#   'not',
#   'spanish',
#   'gustaría',
#   'saber',
#   'qué',
#   'reclamación',
#   'resuelve'],
#  ['cómo',
#   'cancelo',
#   'pedido',
#   'si',
#   'cancelo',
#   'pedido',
#   'recibiré',
#   'reembolso'],
#  ['cómo',
#   'puedo',
#   'recibir',
#   'reembolso',
#   'mediante',
#   'tarjeta',
#   'cómo',
#   'puedo',
#   'recibir',
#   'reembolso',
#   'si',
#   'banco',
#   'ido',
#   'bancarrota'],
#  ['confirmar',
#   'recepción',
#   'pedido',
#   'confirmado',
#   'recepción',
#   'error',
#   'qué',
#   'puedo',
#   'hacer'],
#  ['cómo',
#   'buscar',
#   'identificación',
#   'producto',
#   'puedo',
#   'buscar',
#   'imágenes',
#   'producto'],
#  ['cómo',
#   'pagar',
#   'tarjeta',
#   'débito',
#   'puedo',
#   'pagar',
#   'tarjeta',
#   'débito',
#   'bmo'],
#  ['qué',
#   'pago',
#   'está',
#   'deducido',
#   'incorrectamente',
#   'qué',
#   'pedido',
#   'está',
#   'vacío'],
#  ['depósito',
#   'bancario',
#   'cómo',
#   'recibo',
#   'justificante',
#   'bancario',
#   'dirección',
#   'email'],
#  ['qué',
#   'pago',
#   'está',
#   'deducido',
#   'incorrectamente',
#   'qué',
#   'niver',
#   'membresía',
#   'está',
#   'contado',
#   'incorrectamente'],
#  ['puedo', 'realizar', 'pagos', 'qué', 'cobraron', 'dos', 'pagos'],
#  ['cómo',
#   'utilizo',
#   'servicio',
#   'garantía',
#   'año',
#   'cómo',
#   'puedo',
#   'elegir',
#   'servicio',
#   'mensajería'],
#  ['significa', 'confirmación', 'caducada', 'qué', 'significa', 'nulo'],
#  ['cómo',
#   'puedo',
#   'recibir',
#   'reembolso',
#   'mediante',
#   'tarjeta',
#   'puedo',
#   'recibir',
#   'reembolso'],
#  ['cómo',
#   'puedo',
#   'recibir',
#   'reembolso',
#   'mediante',
#   'tarjeta',
#   'cómo',
#   'puedo',
#   'recibir',
#   'reembolso',
#   'si',
#   'tarjeta',
#   'está',
#   'cancelada'],
#  ['cómo',
#   'establecer',
#   'tarjeta',
#   'principal',
#   'cómo',
#   'pago',
#   'tarjeta',
#   'crédito'],
#  ['ok', 'problema', 'problema', 'pago'],
#  ['hola',
#   'reiteradas',
#   'ocasiones',
#   'intentado',
#   'saber',
#   'pasa',
#   'pedido',
#   'veo',
#   'solucionen',
#   'problema',
#   'problema',
#   'pedido'],
#  ['cómo',
#   'recibir',
#   'devolución',
#   'mediante',
#   'western',
#   'union',
#   'western',
#   'union'],
#  ['qué', 'cerrado', 'pedido', 'qué', 'dice', 'pedido', 'sido', 'cerrado'],
#  ['qué',
#   'pago',
#   'está',
#   'deducido',
#   'incorrectamente',
#   'qué',
#   'pedido',
#   'está',
#   'cerrado',
#   'pago',
#   'deducido'],
#  ['descripción',
#   'mismo',
#   'viene',
#   'reloj',
#   'grande',
#   'impreso',
#   'lamina',
#   'resto',
#   'laminas',
#   'solo',
#   'pensando',
#   'marca',
#   'agua',
#   'similar',
#   'escrow',
#   'depósito',
#   'garantía',
#   'protección',
#   'comprador'],
#  ['quiero', 'hablar', 'agente', 'necesito', 'hablar', 'agente'],
#  ['qué', 'pasará', 'después', 'abrir', 'disputa', 'puedo', 'abrir', 'disputa'],
#  ['buenos', 'días', 'quiero', 'extender', 'tiempo', 'envío', 'días'],
#  ['ver', 'número', 'tarjeta', 'cómo', 'puedo', 'ver', 'historial', 'compras'],
#  ['qué', 'cerrado', 'pedido', 'qué', 'dice', 'pedido', 'sido', 'cerrado'],
#  ['qué',
#   'podido',
#   'procesar',
#   'pago',
#   'razones',
#   'seguridad',
#   'pedido',
#   'sido',
#   'cancelado',
#   'razones',
#   'seguridad'],
#  ['cerre',
#   'pedido',
#   'error',
#   'qué',
#   'puedo',
#   'hacer',
#   'si',
#   'hecho',
#   'pedido',
#   'error'],
#  ['buenos',
#   'días',
#   'vendedor',
#   'envió',
#   'producto',
#   'distinto',
#   'pedí',
#   'enviarme',
#   'indica',
#   'mensaje',
#   'haría',
#   'descuento',
#   'solo',
#   'debería',
#   'pagar',
#   'costo',
#   'envío',
#   'sé',
#   'utilizar',
#   'descuento',
#   'recibí',
#   'cupón',
#   'descuento',
#   'gustaría',
#   'saber',
#   'cómo',
#   'puedo',
#   'usarlo'],
#  ['ayer',
#   'hice',
#   'pedido',
#   'sido',
#   'rechazado',
#   'ustedes',
#   'acabo',
#   'recibir',
#   'email',
#   'diciendo',
#   'pedido',
#   'sido',
#   'cerrado',
#   'pagar',
#   'pagado'],
#  ['necesito',
#   'dinero',
#   'regreso',
#   'abrí',
#   'disputa',
#   'acuerdo',
#   'reembolsar',
#   'dinero'],
#  ['qué',
#   'puedo',
#   'realizar',
#   'pedido',
#   'puedo',
#   'abrir',
#   'disputa',
#   'pedido',
#   'qué',
#   'puedo',
#   'hacer'],
#  ['buenas',
#   'tardes',
#   'abrió',
#   'disputa',
#   'vendedor',
#   'debido',
#   'mercancía',
#   'compré',
#   'defectuoso',
#   'solicitud',
#   'había',
#   'desaparecido',
#   'lista',
#   'tenía',
#   'siquiera',
#   'vuelta',
#   'cómo',
#   'presentar',
#   'disputa',
#   'después',
#   'haber',
#   'recibido',
#   'mercancías',
#   'tiempo',
#   'agotado'],
#  ['puedo',
#   'abrir',
#   'disputas',
#   'cuenta',
#   'desactivada',
#   'seguridad',
#   'qué',
#   'puedo',
#   'abrir',
#   'cesta'],
#  ['devuelto',
#   'menos',
#   'pague',
#   'cancelar',
#   'pedido',
#   'cobrado',
#   'pedido',
#   'sigue',
#   'pendiente',
#   'pago'],
#  ['cómo',
#   'contactar',
#   'vendedor',
#   'debería',
#   'contactar',
#   'vendedor',
#   'realizar',
#   'pago'],
#  ['nombre',
#   'contraseña',
#   'cuenta',
#   'incorrecto',
#   'olvidado',
#   'contraseña',
#   'cuenta'],
#  ['puedo',
#   'saber',
#   'qué',
#   'está',
#   'pasando',
#   'disputa',
#   'producto',
#   'está',
#   'bloqueado',
#   'gustaría',
#   'saber',
#   'qué',
#   'puedo',
#   'hacer'],
#  ['qué',
#   'protección',
#   'comprador',
#   'qué',
#   'cubre',
#   'escrow',
#   'depósito',
#   'garantía',
#   'protección',
#   'comprador'],
#  ['cuánto',
#   'tiempo',
#   'tomará',
#   'verificación',
#   'pago',
#   'pedido',
#   'congelado',
#   'después',
#   'verificación',
#   'pedido',
#   'debido',
#   'vendedor',
#   'está',
#   'siendo',
#   'investigado'],
#  ['qué',
#   'pasará',
#   'después',
#   'abrir',
#   'disputa',
#   'podemos',
#   'llegar',
#   'acuerdo',
#   'después',
#   'abrir',
#   'disputa'],
#  ['problema',
#   'pidiendo',
#   'capcha',
#   'seguir',
#   'usando',
#   'cuenta',
#   'alguna',
#   'manera',
#   'pueda',
#   'hacer',
#   'pedido',
#   'pagar',
#   'él',
#   'usando',
#   'tarjeta',
#   'crédito'],
#  ['cómo',
#   'puedo',
#   'recibir',
#   'reembolso',
#   'mediante',
#   'tarjeta',
#   'cómo',
#   'puedo',
#   'recibir',
#   'reembolso'],
#  ['pagar',
#   'tasas',
#   'aduanas',
#   'importación',
#   'cuál',
#   'id',
#   'tasas',
#   'importación'],
#  ['qué',
#   'pasa',
#   'si',
#   'vendedor',
#   'envía',
#   'pedido',
#   'finalizar',
#   'tiempo',
#   'procesamiento',
#   'qué',
#   'tiempo',
#   'procesamiento'],
#  ['dono',
#   'da',
#   'loja',
#   'não',
#   'responde',
#   'not',
#   'spanish',
#   'cuenta',
#   'da',
#   'opción',
#   'pagar',
#   'western',
#   'union'],
#  ['qué',
#   'cerrado',
#   'pedido',
#   'qué',
#   'pedido',
#   'está',
#   'cerrado',
#   'pedido',
#   'rechazado'],
#  ['abrí',
#   'disputa',
#   'qué',
#   'debo',
#   'hacer',
#   'continuación',
#   'abrí',
#   'disputa',
#   'ahora'],
#  ['recibido', 'pedidos', 'recibido', 'ninguno', 'pedidos', 'aún'],
#  ['qué',
#   'aparece',
#   'pagado',
#   'pago',
#   'sido',
#   'deducido',
#   'tarjeta',
#   'qué',
#   'pago',
#   'sido',
#   'cobrado',
#   'dos',
#   'veces'],
#  ['cómo',
#   'puedo',
#   'recibir',
#   'reembolso',
#   'mediante',
#   'tarjeta',
#   'cómo',
#   'puedo',
#   'recibir',
#   'reembolso',
#   'si',
#   'tarjeta',
#   'existe'],
#  ['quisiera',
#   'ayudes',
#   'pagando',
#   'pedidos',
#   'salio',
#   'pagado',
#   'pedido',
#   'pedido',
#   'pague',
#   'vez',
#   'qué',
#   'hago'],
#  ['cómo', 'hago', 'pedido', 'cómo', 'hago', 'pedido'],
#  ['pago',
#   'siendo',
#   'verificado',
#   'sentimos',
#   'pago',
#   'realizado',
#   'éxito',
#   'cobrado',
#   'dinero',
#   'razón',
#   'pago',
#   'excede',
#   'límite',
#   'crédito',
#   'tarjeta'],
#  ['ayuda', 'encuentro', 'ayuda'],
#  ['dan',
#   'numero',
#   'rastreo',
#   'dhl',
#   'encuentra',
#   'rastreo',
#   'porq',
#   'cómo',
#   'hacer',
#   'seguimiento',
#   'artículos',
#   'enviados',
#   'dhl'],
#  ['si',
#   'hablo',
#   'español',
#   'necesito',
#   'saber',
#   'si',
#   'aceptan',
#   'mastercard'],
#  ['disputa',
#   'abierta',
#   'entiendo',
#   'quieren',
#   'decir',
#   'acabo',
#   'comprar',
#   'producto',
#   'necesito',
#   'envíen',
#   'dirección',
#   'diferente'],
#  ['producto',
#   'recibido',
#   'corresponde',
#   'descripción',
#   'qué',
#   'puedo',
#   'hacer',
#   'cerrado',
#   'ventana',
#   'chat',
#   'equipo',
#   'servicio',
#   'accidente',
#   'qué',
#   'puedo',
#   'hacer'],
#  ['qué',
#   'pasará',
#   'después',
#   'abrir',
#   'disputa',
#   'quiero',
#   'abrir',
#   'disputa'],
#  ['buenos', 'días', 'cuántos', 'días', 'puedo', 'esperar', 'entrega'],
#  ['ninguna',
#   'opciones',
#   'responde',
#   'pregunta',
#   'tiempo',
#   'procesamiento',
#   'pedido',
#   'debajo',
#   'opciones',
#   'tiempo',
#   'entrega',
#   'qué'],
#  ['cancelado', 'pedido', 'cobrado', 'hecho', 'pedido', 'recibido'],
#  ['qué', 'cerrado', 'pedido', 'qué', 'cancelado', 'pedido'],
#  ['qué',
#   'sido',
#   'finalizado',
#   'pedido',
#   'razones',
#   'seguridad',
#   'qué',
#   'disputa',
#   'finalizado'],
#  ['aparece',
#   'monto',
#   'tarjeta',
#   'crédito',
#   'hice',
#   'ningún',
#   'pedido',
#   'qué',
#   'cargo',
#   'tarjeta',
#   'crédito',
#   'si',
#   'hecho',
#   'ningún',
#   'pedido'],
#  ['qué',
#   'aparece',
#   'pagado',
#   'pago',
#   'sido',
#   'deducido',
#   'tarjeta',
#   'qué',
#   'pago',
#   'sido',
#   'hecho',
#   'dos',
#   'veces',
#   'tarjeta',
#   'crédito'],
#  ['producto',
#   'bueno',
#   'puedo',
#   'ponerme',
#   'contacto',
#   'vendedor',
#   'cómo',
#   'contacto',
#   'equipo',
#   'disputas'],
#  ['qué',
#   'pedido',
#   'está',
#   'verificación',
#   'tras',
#   'pago',
#   'qué',
#   'pago',
#   'está',
#   'pendiente',
#   'verificación'],
#  ['hola',
#   'quiero',
#   'realizar',
#   'seguimiento',
#   'pedido',
#   'cómo',
#   'puedo',
#   'saber',
#   'número',
#   'seguimiento',
#   'quiero',
#   'número',
#   'seguimiento'],
#  ['disputa', 'cómo', 'respondo', 'disputa'],
#  ['cancelar', 'pedido', 'quiero', 'cancelar', 'pedido', 'pedido', 'congelado'],
#  ['podido',
#   'pagar',
#   'tarjeta',
#   'debo',
#   'hacer',
#   'intentado',
#   'pagar',
#   'tarjeta',
#   'visa',
#   'débito',
#   'funciona'],
#  ['cómo', 'hago', 'pedido', 'cómo', 'hago', 'pedido'],
#  ['cómo', 'cambio', 'método', 'pago', 'paypal', 'método', 'pago'],
#  ['robot', 'posible', 'recuperar', 'cupón', 'expirado'],
#  ['cuándo',
#   'recibiré',
#   'reembolso',
#   'si',
#   'pago',
#   'tarjeta',
#   'crédito',
#   'qué',
#   'falla',
#   'pago',
#   'tarjeta',
#   'crédito'],
#  ['podido',
#   'pagar',
#   'tarjeta',
#   'debo',
#   'hacer',
#   'cómo',
#   'debo',
#   'pagar',
#   'western',
#   'union'],
#  ['chat', 'linea', 'cómo', 'puedo', 'añadir', 'usuario', 'chat'],
#  ['hola',
#   'quiero',
#   'realizar',
#   'seguimiento',
#   'pedido',
#   'cómo',
#   'puedo',
#   'saber',
#   'número',
#   'seguimiento',
#   'cómo',
#   'introduzco',
#   'número',
#   'seguimiento',
#   'devolver',
#   'pedido'],
#  ['producto',
#   'recibido',
#   'corresponde',
#   'descripción',
#   'qué',
#   'puedo',
#   'hacer',
#   'producto',
#   'recibido',
#   'bueno',
#   'funciona',
#   'qué',
#   'puedo',
#   'hacer'],
#  ['dice',
#   'permiso',
#   'vendedor',
#   'dijo',
#   'había',
#   'stock',
#   'pidió',
#   'cancelarlo'],
#  ['hola', 'eva', 'hola', 'dora'],
#  ['buenas', 'tardes', 'buenas', 'bien'],
#  ['abri', 'disputa', 'recibido', 'paquete', 'recibido', 'paquete'],
#  ['hola',
#   'vendedor',
#   'dijo',
#   'pedido',
#   'extravio',
#   'vendedor',
#   'escribió',
#   'artículo',
#   'está',
#   'disponible'],
#  ['qué', 'pagado', 'pedido', 'qué', 'devuelto', 'paquete'],
#  ['dicen',
#   'mandado',
#   'email',
#   'sé',
#   'dónde',
#   'ahora',
#   'llegado',
#   'email',
#   'dice',
#   'pedido',
#   'sido',
#   'cancelado',
#   'pagué'],
#  ['cómo',
#   'cancelo',
#   'extensión',
#   'tiempo',
#   'procesamiento',
#   'puedo',
#   'preguntar',
#   'tiempo',
#   'procesamiento'],
#  ['agente', 'quiero', 'productos', 'envíen', 'agente', 'china'],
#  ['capaz',
#   'abrir',
#   'disputa',
#   'solicitar',
#   'devolución',
#   'producto',
#   'llegado',
#   'capaz',
#   'chatear',
#   'vendedores'],
#  ['cómo',
#   'puedo',
#   'recibir',
#   'reembolso',
#   'mediante',
#   'tarjeta',
#   'gustaría',
#   'saber',
#   'cómo',
#   'voy',
#   'recibir',
#   'reembolso'],
#  ['qué',
#   'sido',
#   'finalizado',
#   'pedido',
#   'razones',
#   'seguridad',
#   'pedido',
#   'sido',
#   'cerrado',
#   'razones',
#   'seguridad',
#   'qué',
#   'puedo',
#   'hacer'],
#  ['producto',
#   'recibido',
#   'corresponde',
#   'descripción',
#   'qué',
#   'puedo',
#   'hacer',
#   'recibido',
#   'reembolso',
#   'qué',
#   'puedo',
#   'hacer'],
#  ['qué', 'aprobó', 'pago', 'qué', 'pago', 'hecho', 'dos', 'veces'],
#  ['puedo', 'acceder', 'cuenta', 'puedo', 'acceder', 'cuenta'],
#  ['qué',
#   'sido',
#   'finalizado',
#   'pedido',
#   'razones',
#   'seguridad',
#   'qué',
#   'cierran',
#   'pedido',
#   'razones',
#   'seguridad'],
#  ['qué',
#   'sido',
#   'finalizado',
#   'pedido',
#   'razones',
#   'seguridad',
#   'qué',
#   'pedido',
#   'sido',
#   'cerrado',
#   'razones',
#   'seguridad'],
#  ['cómo',
#   'puedo',
#   'conseguir',
#   'facturas',
#   'compras',
#   'cómo',
#   'puedo',
#   'pagar',
#   'compras'],
#  ['producto',
#   'recibido',
#   'corresponde',
#   'descripción',
#   'qué',
#   'puedo',
#   'hacer',
#   'qué',
#   'pasa',
#   'si',
#   'producto',
#   'recibí',
#   'coincide',
#   'descripción'],
#  ['vendedor',
#   'dice',
#   'pedido',
#   'completado',
#   'zapatos',
#   'todavía',
#   'vendedor',
#   'enviado',
#   'productos',
#   'quiero',
#   'cancelar',
#   'pedido'],
#  ['quiero', 'dinero', 'cómo', 'puedo', 'transferir', 'dinero'],
#  ['cómo',
#   'puedo',
#   'transferir',
#   'dinero',
#   'cuenta',
#   'cómo',
#   'puedo',
#   'transferir',
#   'dinero'],
#  ['cómo',
#   'extiendo',
#   'plazo',
#   'procesamiento',
#   'pedido',
#   'cómo',
#   'solicito',
#   'envío',
#   'tiempo',
#   'procesamiento',
#   'expirado'],
#  ['cómo', 'pagar', 'paypal', 'puedo', 'pagar', 'paypal'],
#  ['cómo',
#   'puedo',
#   'recibir',
#   'reembolso',
#   'mediante',
#   'tarjeta',
#   'pedido',
#   'cancelado',
#   'sospechas',
#   'cómo',
#   'recibir',
#   'reembolso'],
#  ['cómo',
#   'puedo',
#   'utilizar',
#   'cupón',
#   'código',
#   'cupón',
#   'cómo',
#   'elimino',
#   'cupón'],
#  ['puedes', 'ayudarme', 'pueden', 'ayudarme', 'buscar', 'producto', 'página'],
#  ['realiza', 'reembolso', 'congelado', 'pedido'],
#  ['pude', 'subir', 'todavía', 'comprobantes', 'puedo', 'subir', 'tandas'],
#  ['qué',
#   'aparece',
#   'pagado',
#   'pago',
#   'sido',
#   'deducido',
#   'tarjeta',
#   'qué',
#   'pago',
#   'sido',
#   'doble'],
#  ['cómo',
#   'puedo',
#   'recibir',
#   'reembolso',
#   'mediante',
#   'tarjeta',
#   'pagué',
#   'mastercard',
#   'cómo',
#   'puedo',
#   'recibir',
#   'reembolso'],
#  ['cuáles',
#   'casos',
#   'típicos',
#   'actividades',
#   'fraudulentas',
#   'cuánto',
#   'gastos',
#   'envío'],
#  ['cómo',
#   'puedo',
#   'recibir',
#   'reembolso',
#   'mediante',
#   'tarjeta',
#   'cómo',
#   'recibir',
#   'reembolso'],
#  ['cuándo',
#   'puedo',
#   'recibir',
#   'reembolso',
#   'cancelado',
#   'pedido',
#   'cuándo',
#   'puedo',
#   'esperar',
#   'reembolso'],
#  ['qué',
#   'cargo',
#   'tarjeta',
#   'crédito',
#   'tenía',
#   'pedido',
#   'problema',
#   'pagar',
#   'online',
#   'tarjeta',
#   'crédito'],
#  ['hice', 'pedido', 'recibido', 'productos', 'pagué', 'pedido', 'recibido'],
#  ['cuánto',
#   'tiempo',
#   'tarda',
#   'producto',
#   'llegar',
#   'dirección',
#   'cuánto',
#   'tarda',
#   'tiempo',
#   'procesamiento'],
#  ['producto', 'igual', 'subiré', 'información', 'tarjeta', 'identidad'],
#  ['vendedor',
#   'accedido',
#   'devolverme',
#   'dinero',
#   'producto',
#   'bueno',
#   'puedo',
#   'contactar',
#   'vendedor'],
#  ['mastercard', 'mastercard'],
#  ['cuándo',
#   'recibiré',
#   'reembolso',
#   'si',
#   'pago',
#   'tarjeta',
#   'crédito',
#   'pagué',
#   'tarjeta',
#   'crédito',
#   'cuándo',
#   'será',
#   'reembolso'],
#  ['cupón', 'puedo', 'usar', 'cupón'],
#  ['vendedor', 'solicito', 'reembolso', 'hice', 'pedido', 'cerraron'],
#  ['vendedor',
#   'responde',
#   'solicitud',
#   'reembolso',
#   'gustaría',
#   'cancelar',
#   'pedido',
#   'vendedor',
#   'responde'],
#  ['qué',
#   'podido',
#   'procesar',
#   'pago',
#   'razones',
#   'seguridad',
#   'pedido',
#   'cancelado',
#   'razones',
#   'seguridad'],
#  ['necesito', 'hacer', 'compra', 'necesito', 'factura'],
#  ['ahora',
#   'pido',
#   'numero',
#   'tracking',
#   'supuestamente',
#   'envio',
#   'pedido',
#   'hace',
#   'vendedor',
#   'dijo',
#   'había',
#   'stock',
#   'pidió',
#   'cancelarlo'],
#  ['qué',
#   'hago',
#   'vendedor',
#   'deje',
#   'enviarme',
#   'mensajes',
#   'ventana',
#   'mensajes',
#   'deja',
#   'escribir',
#   'respuesta',
#   'vendedor',
#   'qué',
#   'pasa'],
#  ['pagar',
#   'pedido',
#   'preventa',
#   'pone',
#   'error',
#   'pago',
#   'cómo',
#   'hago',
#   'seguimiento',
#   'pedido',
#   'pone',
#   'pendiente',
#   'envío'],
#  ['cómo',
#   'puedo',
#   'recibir',
#   'reembolso',
#   'mediante',
#   'tarjeta',
#   'dónde',
#   'puedo',
#   'recibir',
#   'reembolso',
#   'producto',
#   'defectuoso'],
#  ['hoola',
#   'buen',
#   'dia',
#   'publicado',
#   'buen',
#   'número',
#   'preguntas',
#   'proveedores',
#   'respuestas',
#   'aún'],
#  ['qué',
#   'sido',
#   'finalizado',
#   'pedido',
#   'razones',
#   'seguridad',
#   'pedido',
#   'cancelado',
#   'razones',
#   'seguridad'],
#  ['cuándo',
#   'recibiré',
#   'reembolso',
#   'después',
#   'cerrar',
#   'pedido',
#   'pedido',
#   'está',
#   'cerrado',
#   'cuándo',
#   'recibiré',
#   'reembolso'],
#  ['reembolso', 'reembolso'],
#  ['qué',
#   'podido',
#   'procesar',
#   'pago',
#   'razones',
#   'seguridad',
#   'qué',
#   'seguridad',
#   'bloqueado',
#   'transacción'],
#  ['dónde', 'está', 'pedido', 'dónde', 'puedo', 'comprobar', 'pedido'],
#  ['disputa', 'cómo', 'cancelar', 'disputa'],
#  ['cómo', 'hago', 'valoración', 'cómo', 'elimino', 'valoración'],
#  ['van', 'devolver', 'reembolso', 'qué', 'recibo', 'rembolso', 'pedido'],
#  ['problema', 'cuenta', 'problema', 'pagando', 'tarjeta', 'crédito'],
#  ['pedido', 'cerrado', 'qué', 'pedido', 'está', 'cerrado', 'pago', 'deducido'],
#  ['leido', 'llegado'],
#  ['chatear', 'ahora', 'funciona', 'puedo', 'chatear', 'agente'],
#  ['cortado',
#   'conversación',
#   'anterior',
#   'qué',
#   'puntos',
#   'privilegio',
#   'añadido'],
#  ['qué',
#   'sido',
#   'finalizado',
#   'pedido',
#   'razones',
#   'seguridad',
#   'qué',
#   'pedido',
#   'sido',
#   'cancelado',
#   'seguridad'],
#  ['qué',
#   'pago',
#   'está',
#   'deducido',
#   'incorrectamente',
#   'qué',
#   'pago',
#   'está',
#   'pendiente',
#   'verificación'],
#  ['pago', 'está', 'siendo', 'verificado', 'qué', 'pago', 'está', 'verificado'],
#  ['después',
#   'cancelación',
#   'consigo',
#   'recuperar',
#   'dinero',
#   'después',
#   'transacción',
#   'cancelada',
#   'qué',
#   'sistema',
#   'devuelve',
#   'dinero'],
#  ['quiero',
#   'pagar',
#   'puedo',
#   'cómo',
#   'puedo',
#   'pagar',
#   'pedidos',
#   'juntos',
#   'separado'],
#  ['dónde', 'está', 'respuesta', 'dónde', 'está', 'lista', 'deseos'],
#  ['qué',
#   'sido',
#   'finalizado',
#   'pedido',
#   'razones',
#   'seguridad',
#   'pedido',
#   'cerrado',
#   'razones',
#   'seguridad'],
#  ['problemas',
#   'reembolso',
#   'dinero',
#   'recibí',
#   'reembolso',
#   'dinero',
#   'pasado',
#   'dos',
#   'meses',
#   'cuándo',
#   'devolverán',
#   'dinero'],
#  ['qué',
#   'sido',
#   'finalizado',
#   'pedido',
#   'razones',
#   'seguridad',
#   'qué',
#   'pedido',
#   'sido',
#   'pagado'],
#  ['metodos', 'pago', 'qué', 'prueba', 'pago'],
#  ['cuánto',
#   'tiempo',
#   'tarda',
#   'producto',
#   'llegar',
#   'dirección',
#   'si',
#   'pido',
#   'hoy',
#   'cuánto',
#   'tiempo',
#   'tardará',
#   'llegar',
#   'país'],
#  ['vendedor',
#   'está',
#   'siempre',
#   'offline',
#   'responde',
#   'mensajes',
#   'vendedor',
#   'responde',
#   'pedido'],
#  ['podido',
#   'pagar',
#   'tarjeta',
#   'debo',
#   'hacer',
#   'puedo',
#   'pagar',
#   'pedido',
#   'tarjeta',
#   'visa',
#   'débito',
#   'qué',
#   'puedo',
#   'hacer'],
#  ['qué',
#   'puedo',
#   'usar',
#   'cupón',
#   'selección',
#   'qué',
#   'puedo',
#   'usar',
#   'cupón',
#   'selecto'],
#  ['hora',
#   'pagar',
#   'indica',
#   'ponga',
#   'número',
#   'tarjeta',
#   'saldo',
#   'cuándo',
#   'pagar',
#   'tarifa',
#   'protección',
#   'comprador'],
#  ['qué',
#   'pago',
#   'está',
#   'deducido',
#   'incorrectamente',
#   'qué',
#   'reembolso',
#   'está',
#   'pendiente'],
#  ['comentarios',
#   'vendedor',
#   'siendo',
#   'acosado',
#   'vendedor',
#   'revise',
#   'comentarios'],
#  ['ninguna',
#   'respuestas',
#   'entregadas',
#   'corresponde',
#   'sucede',
#   'publicado',
#   'buen',
#   'número',
#   'preguntas',
#   'proveedores',
#   'respuestas',
#   'aún'],
#  ['pedido',
#   'cancelado',
#   'vendedor',
#   'qué',
#   'pedido',
#   'cancelado',
#   'motivo',
#   'riesgo'],
#  ['producto', 'funciona', 'visa', 'débito', 'funciona'],
#  ['cómo',
#   'puedo',
#   'imprimir',
#   'factura',
#   'pedido',
#   'realizado',
#   'necesito',
#   'factura',
#   'pedido',
#   'realizado'],
#  ['qué', 'tarda', 'pago', 'procese', 'qué', 'reclamación', 'tarda'],
#  ['qué',
#   'aparece',
#   'pagado',
#   'pago',
#   'sido',
#   'deducido',
#   'tarjeta',
#   'qué',
#   'pedido',
#   'sido',
#   'cancelado',
#   'pago',
#   'hecho'],
#  ['qué', 'cerrado', 'pedido', 'qué', 'cancelado', 'pedido'],
#  ['hecho', 'compras', 'qué', 'puedo', 'hacer'],
#  ['cambiar',
#   'correo',
#   'electronico',
#   'registro',
#   'cómo',
#   'veo',
#   'registro',
#   'pagos'],
#  ['aviso',
#   'erroneo',
#   'recibí',
#   'email',
#   'aviso',
#   'vendedor',
#   'sospechoso',
#   'actividad',
#   'fraudulenta'],
#  ['cuándo',
#   'recibiré',
#   'reembolso',
#   'si',
#   'pago',
#   'tarjeta',
#   'crédito',
#   'cobran',
#   'tarifa',
#   'servicio',
#   'si',
#   'pago',
#   'pedidos',
#   'tarjeta',
#   'crédito'],
#  ['vendedor',
#   'responde',
#   'qué',
#   'debo',
#   'hacer',
#   'quiero',
#   'cancelar',
#   'pedido',
#   'vendedor',
#   'responde'],
#  ['cómo',
#   'puedo',
#   'recibir',
#   'reembolso',
#   'mediante',
#   'tarjeta',
#   'cómo',
#   'puedo',
#   'recibir',
#   'reembolso'],
#  ['cómo',
#   'puedo',
#   'pagar',
#   'cómo',
#   'puedo',
#   'pagar',
#   'través',
#   'western',
#   'union'],
#  ['qué',
#   'podido',
#   'procesar',
#   'pago',
#   'razones',
#   'seguridad',
#   'qué',
#   'pedido',
#   'sido',
#   'cancelado',
#   'seguridad'],
#  ['puedes', 'escribir', 'español', 'favor', 'cargando', 'favor', 'espere'],
#  ['qué',
#   'pasa',
#   'si',
#   'vendedor',
#   'acepta',
#   'rechaza',
#   'disputa',
#   'plazo',
#   'indicado',
#   'qué',
#   'puedo',
#   'hacer',
#   'si',
#   'vendedor',
#   'rechaza',
#   'solicitud',
#   'cancelación',
#   'pedido'],
#  ['qué',
#   'más',
#   'información',
#   'seguimiento',
#   'paquete',
#   'deseo',
#   'más',
#   'información',
#   'envío',
#   'pedido'],
#  ['producto',
#   'recibido',
#   'corresponde',
#   'descripción',
#   'qué',
#   'puedo',
#   'hacer',
#   'acabo',
#   'pedir',
#   'producto',
#   'online',
#   'puesto',
#   'dirección',
#   'correcta',
#   'qué',
#   'puedo',
#   'hacer'],
#  ['pago', 'quiero', 'cancelar', 'pago'],
#  ['cómo',
#   'puedo',
#   'recibir',
#   'reembolso',
#   'mediante',
#   'tarjeta',
#   'cómo',
#   'recibir',
#   'reembolso',
#   'pedido',
#   'cancelado'],
#  ['qué',
#   'aparece',
#   'pagado',
#   'pago',
#   'sido',
#   'deducido',
#   'tarjeta',
#   'dice',
#   'reembolso',
#   'sido',
#   'aceptado',
#   'aparece',
#   'banco'],
#  ['cómo',
#   'cambio',
#   'dirección',
#   'email',
#   'cómo',
#   'cambio',
#   'dirección',
#   'email',
#   'registrada'],
#  ['cómo',
#   'recuperar',
#   'contraseña',
#   'cómo',
#   'puedo',
#   'restablecer',
#   'contraseña'],
#  ['parece',
#   'correcto',
#   'haga',
#   'pedido',
#   'informen',
#   'vacaciones',
#   'si',
#   'asi',
#   'hecho',
#   'pedido',
#   'recibo',
#   'error',
#   'hago',
#   'pedido'],
#  ['qué',
#   'aparece',
#   'pagado',
#   'pago',
#   'sido',
#   'deducido',
#   'tarjeta',
#   'pagado',
#   'pedido',
#   'aparece',
#   'aún',
#   'pagado',
#   'qué',
#   'hacer'],
#  ['qué',
#   'puedo',
#   'usar',
#   'cupón',
#   'selección',
#   'qué',
#   'puedo',
#   'canjear',
#   'cupón'],
#  ['cómo',
#   'puedo',
#   'recibir',
#   'reembolso',
#   'cómo',
#   'puedo',
#   'recibir',
#   'reembolso',
#   'si',
#   'tarjeta',
#   'está',
#   'cancelada'],
#  ['qué',
#   'puedo',
#   'realizar',
#   'pedido',
#   'solo',
#   'quiero',
#   'realizar',
#   'pedido',
#   'producto',
#   'instantáneamente'],
#  ['qué', 'tarda', 'pago', 'procese', 'qué', 'pago', 'hecho', 'dos', 'veces'],
#  ['puedo',
#   'pagar',
#   'paypal',
#   'quiero',
#   'pagar',
#   'productos',
#   'paypal',
#   'posible'],
#  ['abrir', 'disputa', 'pedidos', 'terminados', 'opción', 'abrir', 'disputa'],
#  ['disputa', 'puedo', 'abrir', 'disputa'],
#  ['acabo',
#   'recibir',
#   'correo',
#   'electrónico',
#   'diciendo',
#   'pedido',
#   'cerrado',
#   'haber',
#   'pagado',
#   'pagué',
#   'recibido',
#   'email',
#   'diciendo',
#   'pedido',
#   'sido',
#   'cancelado',
#   'falta',
#   'pago'],
#  ['cómo', 'hacer', 'compra', 'plazos', 'quiero', 'compra', 'rápida'],
#  ['qué',
#   'hago',
#   'si',
#   'cantidad',
#   'pago',
#   'deducido',
#   'incorrecto',
#   'qué',
#   'hago',
#   'si',
#   'cantidad',
#   'cobrada',
#   'pago',
#   'incorrecta'],
#  ['cuándo',
#   'puedo',
#   'recibir',
#   'reembolso',
#   'cuándo',
#   'puedo',
#   'recibir',
#   'pedido'],
#  ['cuáles',
#   'métodos',
#   'ponerse',
#   'contacto',
#   'vendedores',
#   'puedo',
#   'encontrar',
#   'western',
#   'union',
#   'métodos',
#   'pago'],
#  ['qué',
#   'pago',
#   'está',
#   'deducido',
#   'incorrectamente',
#   'qué',
#   'pedido',
#   'está',
#   'aquí',
#   'aún'],
#  ['qué',
#   'podido',
#   'procesar',
#   'pago',
#   'razones',
#   'seguridad',
#   'qué',
#   'pedido',
#   'sido',
#   'cerrado',
#   'razones',
#   'seguridad'],
#  ['puedo',
#   'comunicar',
#   'den',
#   'solucion',
#   'gustaría',
#   'productos',
#   'enviaran',
#   'nueva',
#   'dirección'],
#  ['buenos',
#   'días',
#   'después',
#   'cancelación',
#   'cuántos',
#   'días',
#   'devuelven',
#   'dinero'],
#  ['qué',
#   'pedido',
#   'está',
#   'verificación',
#   'tras',
#   'pago',
#   'qué',
#   'tras',
#   'hacer',
#   'clic',
#   'pagar',
#   'pedido',
#   'envía',
#   'vuelta',
#   'inicio',
#   'sesión'],
#  ['coñazo', 'qué', 'quieren', 'decir', 'tendré', 'pagar', 'tarifa'],
#  ['pedido', 'pagado', 'descontaron', 'tarjeta', 'pagado', 'pedido'],
#  ['cómo',
#   'cambiar',
#   'dirección',
#   'envío',
#   'cómo',
#   'añado',
#   'dirección',
#   'envío'],
#  ['cómo', 'puede', 'reembolsar', 'puede', 'hacer', 'pago', 'través', 'paypal'],
#  ['vendedor',
#   'fraude',
#   'cómo',
#   'puedo',
#   'informar',
#   'cómo',
#   'puede',
#   'saber',
#   'si',
#   'vendedor',
#   'legítimo'],
#  ['gracias', 'gracias'],
#  ['dónde',
#   'puedo',
#   'encontrar',
#   'valoración',
#   'hecho',
#   'cómo',
#   'puedo',
#   'encontrar',
#   'valoración',
#   'dejé'],
#  ['buenos', 'días', 'cuántos', 'días', 'tardará', 'llegar', 'destino'],
#  ['artículos',
#   'venta',
#   'cómo',
#   'puedo',
#   'eliminar',
#   'artículos',
#   'recibidos',
#   'artículos',
#   'pendientes',
#   'pago',
#   'lista',
#   'pedidos'],
#  ['disputa', 'consigo', 'abrir', 'disputa'],
#  ['qué',
#   'puedo',
#   'encontrar',
#   'pedido',
#   'cuenta',
#   'qué',
#   'cobrado',
#   'dos',
#   'veces',
#   'cuenta',
#   'pedido'],
#  ['deseo', 'cambiar', 'número', 'tarjeta', 'crédito', 'tarjeta', 'crédito'],
#  ['producto',
#   'recibido',
#   'corresponde',
#   'descripción',
#   'qué',
#   'puedo',
#   'hacer',
#   'satisfecho',
#   'producto',
#   'recibido',
#   'qué',
#   'puedo',
#   'hacer'],
#  ['buenos', 'días', 'cuántos', 'días', 'llegará', 'reembolso'],
#  ['qué',
#   'protección',
#   'comprador',
#   'escrow',
#   'depósito',
#   'garantía',
#   'protección',
#   'comprador'],
#  ['cómo',
#   'cancelo',
#   'pedido',
#   'cómo',
#   'cancelo',
#   'pedido',
#   'pendiente',
#   'envío'],
#  ['recibido',
#   'reembolso',
#   'cancelación',
#   'orden',
#   'qué',
#   'recibido',
#   'reembolso',
#   'menor'],
#  ['problemas', 'garantia', 'problemas', 'pedido'],
#  ['cómo',
#   'puedo',
#   'pagar',
#   'webmoney',
#   'qué',
#   'puedo',
#   'pagar',
#   'vía',
#   'webmoney'],
#  ['pasa',
#   'si',
#   'quedo',
#   'mal',
#   'direccion',
#   'entrega',
#   'qué',
#   'pasa',
#   'si',
#   'producto',
#   'recibí',
#   'coincide',
#   'descripción'],
#  ['cómo', 'recupero', 'cupón', 'cómo', 'puedo', 'usar', 'cupón'],
#  ['qué',
#   'aparece',
#   'pagado',
#   'pago',
#   'sido',
#   'deducido',
#   'tarjeta',
#   'qué',
#   'piden',
#   'pago',
#   'hecho',
#   'pago'],
#  ['quiero',
#   'alguien',
#   'responda',
#   'dinero',
#   'qué',
#   'reembolsado',
#   'menos',
#   'dinero',
#   'cobraron'],
#  ['buenos', 'días', 'buenos', 'días'],
#  ['cómo', 'reviso', 'valoración', 'cómo', 'cambio', 'valoración', 'recibida'],
#  ['qué',
#   'está',
#   'disponible',
#   'cuenta',
#   'qué',
#   'cuenta',
#   'está',
#   'temporalmente',
#   'disponible'],
#  ['cómo',
#   'recibiré',
#   'reembolso',
#   'pedido',
#   'cuándo',
#   'recibiré',
#   'reembolso',
#   'pedido'],
#  ['podido',
#   'pagar',
#   'tarjeta',
#   'debo',
#   'hacer',
#   'puedo',
#   'pagar',
#   'tarjeta',
#   'débito',
#   'qué',
#   'puedo',
#   'hacer'],
#  ['qué',
#   'puedo',
#   'dejar',
#   'comentarios',
#   'pedido',
#   'siendo',
#   'acosado',
#   'vendedor',
#   'revise',
#   'comentarios'],
#  ['cómo',
#   'hacer',
#   'pago',
#   'través',
#   'boleto',
#   'cómo',
#   'funciona',
#   'pago',
#   'boleto'],
#  ['nombre',
#   'envio',
#   'western',
#   'union',
#   'cómo',
#   'recibo',
#   'reembolso',
#   'western',
#   'union'],
#  ['producto',
#   'recibido',
#   'bueno',
#   'funciona',
#   'qué',
#   'puedo',
#   'hacer',
#   'código',
#   'verificación',
#   'funciona',
#   'qué',
#   'puedo',
#   'hacer'],
#  ['cómo',
#   'puedo',
#   'gestionar',
#   'cesta',
#   'compras',
#   'puedo',
#   'poner',
#   'más',
#   'producto',
#   'cesta'],
#  ['podido',
#   'pagar',
#   'tarjeta',
#   'debo',
#   'hacer',
#   'pagado',
#   'tarjeta',
#   'crédito',
#   'dos',
#   'veces',
#   'mismo',
#   'producto',
#   'qué',
#   'puedo',
#   'hacer'],
#  ['hice', 'pedido', 'hice', 'pedido', 'mal'],
#  ['qué',
#   'pasará',
#   'después',
#   'abrir',
#   'disputa',
#   'puedo',
#   'abrir',
#   'disputa',
#   'después',
#   'confirmar',
#   'recibido',
#   'pedido'],
#  ['aún', 'sé', 'resultado', 'quiero', 'saber', 'cómo', 'sé', 'seguro'],
#  ['hola',
#   'mayoria',
#   'veces',
#   'intento',
#   'dar',
#   'valoracion',
#   'puedo',
#   'hacerlo',
#   'sale',
#   'pagina',
#   'superpuesta',
#   'pone',
#   'dar',
#   'retroalimentacion',
#   'dar',
#   'retroalimentacion',
#   'qué',
#   'cobró',
#   'dos',
#   'veces'],
#  ['todavia',
#   'obtengo',
#   'respuesta',
#   'pedidos',
#   'cómo',
#   'gestionar',
#   'pedidos'],
#  ['problemas',
#   'pagar',
#   'si',
#   'uso',
#   'mastercard',
#   'pagar',
#   'pagar',
#   'algún',
#   'cargo'],
#  ['bloquearon',
#   'cuenta',
#   'necesito',
#   'cuenta',
#   'da',
#   'opción',
#   'pagar',
#   'western',
#   'union'],
#  ['sirve', 'ayuda', 'favor', 'denme', 'número', 'línea', 'ayuda'],
#  ['qué',
#   'pago',
#   'sido',
#   'deducido',
#   'dos',
#   'veces',
#   'qué',
#   'sido',
#   'cobrado',
#   'dos',
#   'veces'],
#  ['cancelación', 'transacción', 'cancelación', 'miembro'],
#  ['cómo',
#   'pagar',
#   'tarjeta',
#   'crédito',
#   'puedo',
#   'pagar',
#   'pedido',
#   'tarjeta',
#   'crédito',
#   'brasileña'],
#  ['qué',
#   'podido',
#   'procesar',
#   'pago',
#   'razones',
#   'seguridad',
#   'razones',
#   'seguridad',
#   'sistema',
#   'necesitamos',
#   'verificar',
#   'identidad'],
#  ['qué', 'cerrado', 'pedido', 'qué', 'borrado', 'perfil'],
#  ['vendedor',
#   'realizado',
#   'reembolso',
#   'reenviado',
#   'pedido',
#   'intentado',
#   'ponerme',
#   'contacto',
#   'él',
#   'ignora',
#   'pagado',
#   'pedido',
#   'pago',
#   'éxito',
#   'cobraron',
#   'dinero'],
#  ['podido',
#   'pagar',
#   'tarjeta',
#   'debo',
#   'hacer',
#   'puedo',
#   'pagar',
#   'pedido',
#   'tarjeta'],
#  ['cómo',
#   'puedo',
#   'saber',
#   'dónde',
#   'está',
#   'pedido',
#   'cómo',
#   'saber',
#   'si',
#   'pedido',
#   'está',
#   'cancelado'],
#  ['pago', 'pago', 'envío'],
#  ['puedo', 'pagar', 'puedo', 'pagar', 'paypal'],
#  ['parecer',
#   'pedidos',
#   'realizados',
#   'cancelados',
#   'serán',
#   'cancelados',
#   'hago',
#   'dónde',
#   'puedo',
#   'ver',
#   'mensajes',
#   'enviado',
#   'proveedor'],
#  ['recibido', 'reembolso', 'qué', 'recibido', 'reembolso', 'pedido'],
#  ['cómo', 'pagar', 'western', 'union', 'cómo', 'pago', 'western', 'union'],
#  ['puedo',
#   'cambiar',
#   'detalles',
#   'pedido',
#   'tamaño',
#   'envío',
#   'etc',
#   'detalles',
#   'seguimiento',
#   'pedido',
#   'devuelto',
#   'añadido',
#   'qué',
#   'puedo',
#   'hacer'],
#  ['qué',
#   'pedido',
#   'está',
#   'verificación',
#   'tras',
#   'pago',
#   'qué',
#   'pedido',
#   'está',
#   'cerrado',
#   'pago',
#   'deducido'],
#  ['vendedor',
#   'dice',
#   'enviará',
#   'producto',
#   'intento',
#   'pagar',
#   'dice',
#   'sistema',
#   'está',
#   'disponible'],
#  ['cómo',
#   'puedo',
#   'recibir',
#   'reembolso',
#   'mediante',
#   'tarjeta',
#   'cómo',
#   'puedo',
#   'recibir',
#   'reembolso',
#   'si',
#   'tarjeta',
#   'caducado'],
#  ['cómo',
#   'puedo',
#   'combinar',
#   'varios',
#   'pedidos',
#   'solo',
#   'pago',
#   'cómo',
#   'puedo',
#   'combinar',
#   'gastos',
#   'envío',
#   'si',
#   'pido',
#   'varios',
#   'artículos',
#   'vendedor'],
#  ['qué',
#   'hago',
#   'si',
#   'cantidad',
#   'pago',
#   'deducido',
#   'incorrecto',
#   'qué',
#   'hacer',
#   'si',
#   'vendedor',
#   'enviado',
#   'productos',
#   'servicio',
#   'mensajería',
#   'incorrecto'],
#  ['qué',
#   'pago',
#   'está',
#   'deducido',
#   'incorrectamente',
#   'qué',
#   'puedo',
#   'hacer',
#   'si',
#   'vendedor',
#   'escribe',
#   'nombre',
#   'incorrectamente'],
#  ['algún',
#   'error',
#   'opciones',
#   'pago',
#   'puedo',
#   'registrarme',
#   'mensaje',
#   'error'],
#  ['envio',
#   'mensajes',
#   'vendedor',
#   'resuelve',
#   'devuelvan',
#   'dinero',
#   'recibido',
#   'pedido',
#   'quiero',
#   'devuelvan',
#   'dinero'],
#  ['podido',
#   'pagar',
#   'tarjeta',
#   'debo',
#   'hacer',
#   'qué',
#   'debo',
#   'hacer',
#   'si',
#   'pago',
#   'doku',
#   'fallado'],
#  ['buen',
#   'día',
#   'publicado',
#   'buen',
#   'número',
#   'preguntas',
#   'proveedores',
#   'respuestas',
#   'aún'],
#  ['cuánto',
#   'tarda',
#   'proveedor',
#   'procesar',
#   'pedido',
#   'cuánto',
#   'tarda',
#   'actualizar',
#   'precio',
#   'producto'],
#  ['aparece',
#   'tiburón',
#   'medio',
#   'carretera',
#   'puedo',
#   'organizar',
#   'envío',
#   'producto',
#   'dirección',
#   'china'],
#  ['puedo', 'abrir', 'disputa', 'necesito', 'abrir', 'disputa'],
#  ['tiempo',
#   'procesamiento',
#   'terminó',
#   'pedido',
#   'automáticamente',
#   'cancelado',
#   'tiempo',
#   'procesamiento'],
#  ['hola', 'hola'],
#  ['buenos', 'días', 'cuántos', 'días', 'recibiré', 'pedido'],
#  ['qué',
#   'pago',
#   'está',
#   'deducido',
#   'incorrectamente',
#   'qué',
#   'pago',
#   'está',
#   'congelado'],
#  ['nombre',
#   'contraseña',
#   'cuenta',
#   'incorrecto',
#   'código',
#   'seguimiento',
#   'incorrecto',
#   'así',
#   'puedo',
#   'saber',
#   'dónde',
#   'está',
#   'pedido'],
#  ['hola', 'quiero', 'ayuda', 'necesito', 'ayuda', 'localización', 'pedido'],
#  ['número',
#   'pedido',
#   'igual',
#   'número',
#   'cuenta',
#   'qué',
#   'recibido',
#   'error',
#   'número',
#   'cuenta',
#   'bancaria',
#   'válido'],
#  ['límite',
#   'máximo',
#   'transacciones',
#   'cómo',
#   'comprobar',
#   'fecha',
#   'límite',
#   'protección',
#   'comprador'],
#  ['pedido',
#   'entregado',
#   'persona',
#   'pedido',
#   'entregado',
#   'dirección',
#   'equivocada'],
#  ['abrí',
#   'disputa',
#   'sido',
#   'solucionado',
#   'absolutamente',
#   'abrí',
#   'disputa',
#   'vendedor',
#   'rechazó',
#   'quedó',
#   'dinero'],
#  ['recibi',
#   'pedido',
#   'dice',
#   'dpi',
#   'pague',
#   'quiero',
#   'compras',
#   'qué',
#   'pagué',
#   'productos',
#   'pedido',
#   'cancelado'],
#  ['aun', 'recibido', 'producto', 'producto', 'recibido', 'funciona'],
#  ['qué',
#   'aparece',
#   'pagado',
#   'pago',
#   'sido',
#   'deducido',
#   'tarjeta',
#   'qué',
#   'pedido',
#   'está',
#   'cerrado',
#   'pago',
#   'deducido'],
#  ['reembolso', 'puedo', 'reclamar', 'reembolso'],
#  ['qué',
#   'pasará',
#   'después',
#   'abrir',
#   'disputa',
#   'necesito',
#   'abrir',
#   'disputa'],
#  ['puedo', 'pedir', 'ahora'],
#  ['chatear', 'ahora', 'funciona', 'dónde', 'está', 'ahora'],
#  ['pasame', 'agente', 'agente', 'atención', 'cliente'],
#  ['qué',
#   'podido',
#   'procesar',
#   'pago',
#   'razones',
#   'seguridad',
#   'qué',
#   'pago',
#   'hecho',
#   'dos',
#   'veces'],
#  ['cómo',
#   'pagar',
#   'western',
#   'union',
#   'cómo',
#   'puedo',
#   'pagar',
#   'western',
#   'union'],
#  ['pasa', 'pago', 'qué', 'pasa', 'disputa', 'qué', 'aún', 'reembolso'],
#  ['hola', 'eva', 'hola'],
#  ['cómo',
#   'pagar',
#   'tarjeta',
#   'crédito',
#   'vinculada',
#   'qué',
#   'fallo',
#   'pagar',
#   'tarjeta',
#   'crédito'],
#  ['podido',
#   'pagar',
#   'tarjeta',
#   'debo',
#   'hacer',
#   'qué',
#   'debo',
#   'hacer',
#   'si',
#   'pago',
#   'webmoney',
#   'fallado'],
#  ['lista', 'compartir', 'lista', 'deseos'],
#  ['pedidos', 'qué', 'puedo', 'ver', 'últimos', 'pedidos'],
#  ['buenos', 'días', 'cuántos', 'días', 'tardará', 'llegar', 'destino'],
#  ['dónde', 'está', 'reembolso', 'dónde', 'está', 'buzón', 'email'],
#  ['pedido', 'finalizado', 'pedido', 'congelado'],
#  ['cómo', 'hago', 'pedido', 'cómo', 'hago', 'pedido'],
#  ['dinero', 'cómo', 'puedo', 'transferir', 'dinero'],
#  ['cómo',
#   'utilizo',
#   'servicio',
#   'garantía',
#   'año',
#   'qué',
#   'pasará',
#   'después',
#   'haber',
#   'enviado',
#   'solicitud',
#   'servicio',
#   'garantía'],
#  ['pedido',
#   'pendiente',
#   'recepción',
#   'todavía',
#   'recibido',
#   'producto',
#   'cancelado',
#   'pedido',
#   'pone',
#   'pendiente',
#   'cancelación'],
#  ['pedido',
#   'llegó',
#   'terminado',
#   'disputa',
#   'plazo',
#   'respuesta',
#   'vendedor',
#   'terminado'],
#  ['quiero',
#   'vestido',
#   'blanco',
#   'voy',
#   'casar',
#   'quiero',
#   'saber',
#   'si',
#   'vestido',
#   'puede',
#   'hacer',
#   'negro',
#   'rojo'],
#  ['qué',
#   'aparece',
#   'pagado',
#   'pago',
#   'sido',
#   'deducido',
#   'tarjeta',
#   'piden',
#   'paguemos',
#   'pago',
#   'sido',
#   'hecho'],
#  ['negocio',
#   'dropshipping',
#   'necesito',
#   'hacer',
#   'pedidos',
#   'pagos',
#   'tarjeta',
#   'hace',
#   'tres',
#   'dias',
#   'dijeron',
#   'seguridad',
#   'verificar',
#   'tarjeta',
#   'mande',
#   'documento',
#   'todavia',
#   'verifican',
#   'puedo',
#   'hacer',
#   'pagos',
#   'puedo',
#   'hacer',
#   'pagos',
#   'paypal'],
#  ['vendedor',
#   'dice',
#   'cancele',
#   'pedido',
#   'devolverme',
#   'dinero',
#   'enviarán',
#   'email',
#   'hacerme',
#   'saber',
#   'dinero',
#   'sido',
#   'reembolsado'],
#  ['qué',
#   'aparece',
#   'pagado',
#   'pago',
#   'sido',
#   'deducido',
#   'tarjeta',
#   'qué',
#   'pedido',
#   'sido',
#   'pagado'],
#  ['quiero', 'hablar', 'alguien', 'español', 'página', 'está', 'español'],
#  ['podido', 'pagar', 'tarjeta', 'debo', 'hacer', 'puedo', 'pagar', 'tarjeta'],
#  ['vendedor', 'vendedor', 'responde'],
#  ['qué',
#   'puedo',
#   'dejar',
#   'comentarios',
#   'pedido',
#   'qué',
#   'puedo',
#   'ver',
#   'pedido'],
#  ['hola',
#   'q',
#   'tal',
#   'quiero',
#   'saber',
#   'abro',
#   'disputa',
#   'q',
#   'devuelvan',
#   'dinero',
#   'pedido',
#   'vendedor',
#   'aviso',
#   'aduana',
#   'pais',
#   'envio',
#   'paquete',
#   'nuevamente',
#   'gracias',
#   'enviarán',
#   'email',
#   'hacerme',
#   'saber',
#   'dinero',
#   'sido',
#   'reembolsado'],
#  ['necesito', 'ayuda', 'número', 'teléfono', 'acepta', 'ayuda', 'favor'],
#  ['pedido',
#   'dice',
#   'pedido',
#   'cancelado',
#   'pedido',
#   'cancelado',
#   'dinero',
#   'aún',
#   'sigue',
#   'retenido'],
#  ['ninguna',
#   'zapatos',
#   'verdes',
#   'recibido',
#   'ninguna',
#   'confirmación',
#   'después',
#   'pagar',
#   'pedido'],
#  ['atencion', 'cliente', 'online', 'puede', 'llamar', 'atención', 'cliente'],
#  ['hice', 'pago', 'aparece', 'pagado'],
#  ['abrí',
#   'disputa',
#   'ahora',
#   'abrí',
#   'disputa',
#   'vendedor',
#   'rechazó',
#   'quedó',
#   'dinero'],
#  ['qué',
#   'hago',
#   'si',
#   'cantidad',
#   'pago',
#   'deducido',
#   'incorrecto',
#   'qué',
#   'cobrado',
#   'cantidad',
#   'dos',
#   'veces',
#   'tarjeta',
#   'crédito'],
#  ['dónde', 'está', 'respuesta', 'dónde', 'está', 'respuesta'],
#  ['cómo',
#   'puedo',
#   'usar',
#   'nueva',
#   'dirección',
#   'correo',
#   'electrónico',
#   'cuenta',
#   'cómo',
#   'puedo',
#   'editar',
#   'dirección',
#   'envío'],
#  ['contactar',
#   'proveedor',
#   'puedo',
#   'escribir',
#   'caja',
#   'texto',
#   'contactar',
#   'proveedor'],
#  ['coñazo', 'parece', 'puedo', 'hacer', 'pedidos'],
#  ['qué',
#   'aparece',
#   'pagado',
#   'pago',
#   'sido',
#   'deducido',
#   'tarjeta',
#   'qué',
#   'pago',
#   'está',
#   'siendo',
#   'verificado',
#   'vez',
#   'si',
#   'sido',
#   'confirmado'],
#  ['qué', 'puedo', 'ver', 'precio', 'descuento', 'qué', 'ajustado', 'precio'],
#  ['cómo',
#   'hacer',
#   'pago',
#   'través',
#   'boleto',
#   'cómo',
#   'hago',
#   'pago',
#   'boleto'],
#  ['qué',
#   'podido',
#   'procesar',
#   'pago',
#   'razones',
#   'seguridad',
#   'qué',
#   'cerró',
#   'pedido',
#   'razones',
#   'seguridad'],
#  ['devolucion',
#   'dinero',
#   'quiero',
#   'cancelar',
#   'pedido',
#   'recibir',
#   'dinero',
#   'vuelta'],
#  ['qué', 'congelado', 'pedido', 'qué', 'pedido', 'está', 'congelado'],
#  ['sistema', 'deja', 'pagar', 'deja', 'iniciar', 'sesión'],
#  ['recibido',
#   'mensaje',
#   'pagado',
#   'recibido',
#   'mensaje',
#   'banco',
#   'qué',
#   'puedo',
#   'hacer'],
#  ['qué',
#   'protección',
#   'comprador',
#   'puedo',
#   'pagar',
#   'paypal',
#   'vía',
#   'protección',
#   'comprador'],
#  ['qué', 'protección', 'comprador', 'qué', 'protección', 'comprador'],
#  ['cómo',
#   'modificar',
#   'reembolso',
#   'disputa',
#   'quiero',
#   'reembolso',
#   'cómo',
#   'hago',
#   'disputa',
#   'resuelva'],
#  ['cómo',
#   'cancela',
#   'pedido',
#   'pagado',
#   'cómo',
#   'hago',
#   'pedido',
#   'envíe',
#   'rápidamente'],
#  ['dinero',
#   'costo',
#   'marca',
#   'ceros',
#   'cómo',
#   'cambio',
#   'valoración',
#   'vendedor',
#   'productos'],
#  ['vendedor',
#   'respondió',
#   'pedido',
#   'nunca',
#   'llegó',
#   'hice',
#   'pedido',
#   'vendedor',
#   'pidió',
#   'cancelarlo'],
#  ['alguien', 'ayuda', 'resolver', 'disputa', 'disputa', 'resolver'],
#  ['apertura',
#   'disputa',
#   'tiempo',
#   'finalizó',
#   'tiempo',
#   'procesamiento',
#   'terminado',
#   'vendedor',
#   'enviado',
#   'mercancia'],
#  ['pagar',
#   'tarjeta',
#   'credito',
#   'dice',
#   'error',
#   'pago',
#   'puedo',
#   'pagar',
#   'pedido',
#   'tarjeta',
#   'crédito',
#   'brasileña'],
#  ['segunda',
#   'vez',
#   'accedo',
#   'primera',
#   'vez',
#   'inicio',
#   'sesión',
#   'recibido',
#   'cupón',
#   'gratuito'],
#  ['hola',
#   'ayudame',
#   'consulta',
#   'apelacion',
#   'puedo',
#   'pagar',
#   'tarjeta',
#   'banco',
#   'chino'],
#  ['cómo',
#   'hacer',
#   'pago',
#   'través',
#   'boleto',
#   'cómo',
#   'pagar',
#   'través',
#   'webmoney'],
#  ['producto',
#   'recibido',
#   'corresponde',
#   'descripción',
#   'qué',
#   'puedo',
#   'hacer',
#   'pagado',
#   'recibido',
#   'mensaje',
#   'banco',
#   'qué',
#   'puedo',
#   'hacer'],
#  ['problema',
#   'pedido',
#   'llego',
#   'vendedor',
#   'pidio',
#   'tiempo',
#   'mensaje',
#   'reporte',
#   'llego',
#   'responde',
#   'puedo',
#   'abrir',
#   'disputa',
#   'problema',
#   'pago'],
#  ['cómo',
#   'puedo',
#   'recibir',
#   'reembolso',
#   'cómo',
#   'puedo',
#   'recibir',
#   'reembolso',
#   'si',
#   'banco',
#   'ido',
#   'bancarrota'],
#  ['puedo',
#   'abrir',
#   'disputa',
#   'cómo',
#   'puedo',
#   'abrir',
#   'disputa',
#   'pedido',
#   'cerrado'],
#  ['qué', 'cerrado', 'pedido', 'qué', 'devuelto', 'paquete'],
#  ['dónde',
#   'puedo',
#   'ver',
#   'información',
#   'personal',
#   'dónde',
#   'puedo',
#   'ver',
#   'mensajes',
#   'enviado',
#   'proveedor'],
#  ['pedido',
#   'está',
#   'cancelado',
#   'dinero',
#   'reembolsado',
#   'qué',
#   'cancelado',
#   'pedido',
#   'devolvieron',
#   'dinero'],
#  ['peso', 'paquete', 'diferente', 'anuncio', 'anuncio', 'auténtico'],
#  ['puedo',
#   'generar',
#   'invoice',
#   'comprobante',
#   'linea',
#   'puedo',
#   'pagar',
#   'pedido',
#   'dos',
#   'pagos'],
#  ['cómo', 'cambiar', 'dirección', 'problema', 'cambiar', 'dirección'],
#  ['cómo', 'hago', 'valoración', 'cómo', 'dejo', 'valoración', 'anónima'],
#  ['producto',
#   'recibido',
#   'corresponde',
#   'descripción',
#   'qué',
#   'puedo',
#   'hacer',
#   'qué',
#   'garantías',
#   'recibiré',
#   'producto',
#   'pagado'],
#  ['vendedor',
#   'indica',
#   'aun',
#   'pasa',
#   'pago',
#   'gustaría',
#   'cancelar',
#   'pedido',
#   'vendedor',
#   'responde'],
#  ['cuándo',
#   'puedo',
#   'recibir',
#   'reembolso',
#   'cuándo',
#   'puedo',
#   'recibir',
#   'reembolso',
#   'completo'],
#  ['encontrar', 'mercancia', 'puedo', 'encontrar', 'cuenta'],
#  ['servicio',
#   'malo',
#   'favor',
#   'revisen',
#   'consulta',
#   'puede',
#   'ser',
#   'contesten',
#   'muchas',
#   'cosas',
#   'hoy',
#   'quiero',
#   'saber',
#   'lean',
#   'revisen',
#   'consulta',
#   'cómo',
#   'pido',
#   'devuelvan',
#   'dinero'],
#  ['cómo',
#   'cambio',
#   'dirección',
#   'email',
#   'cómo',
#   'ocultar',
#   'dirección',
#   'email'],
#  ['qué',
#   'podido',
#   'procesar',
#   'pago',
#   'razones',
#   'seguridad',
#   'qué',
#   'está',
#   'cerrado',
#   'razones',
#   'seguridad'],
#  ['vendedor',
#   'responde',
#   'qué',
#   'debo',
#   'hacer',
#   'qué',
#   'debo',
#   'hacer',
#   'si',
#   'pago',
#   'doku',
#   'fallado'],
#  ['cobraron',
#   'pedido',
#   'existe',
#   'envie',
#   'email',
#   'dijeron',
#   'recibo',
#   'respuesta',
#   'recibido',
#   'pedido',
#   'número',
#   'seguimiento',
#   'dieron',
#   'está',
#   'mal'],
#  ['ninguna',
#   'recibido',
#   'ninguna',
#   'confirmación',
#   'después',
#   'pagar',
#   'pedido'],
#  ['qué',
#   'dirección',
#   'electrónica',
#   'puedo',
#   'enviar',
#   'documentos',
#   'verificación',
#   'qué',
#   'pasa',
#   'si',
#   'quiero',
#   'enviar',
#   'extracto',
#   'verificación'],
#  ['vendedor',
#   'fraude',
#   'cómo',
#   'puedo',
#   'informar',
#   'cómo',
#   'puedo',
#   'enviar',
#   'pregunta',
#   'vendedor'],
#  ['cuándo',
#   'recibiré',
#   'reembolso',
#   'si',
#   'pago',
#   'tarjeta',
#   'crédito',
#   'pagado',
#   'tarjeta',
#   'crédito',
#   'cuándo',
#   'será',
#   'confirmado',
#   'pago'],
#  ['hola',
#   'problemas',
#   'depósitos',
#   'problemas',
#   'corregir',
#   'dirección',
#   'envío'],
#  ['hicieron', 'mandar', 'telefono', 'polonia', 'sistema', 'deja', 'pagar'],
#  ['recibido', 'facturas', 'recibido', 'artículos', 'proveedor', 'envió'],
#  ['puedo',
#   'pagar',
#   'mediante',
#   'western',
#   'union',
#   'cómo',
#   'puedo',
#   'pagar',
#   'western',
#   'union'],
#  ['cómo',
#   'recupero',
#   'cupón',
#   'cómo',
#   'recupero',
#   'pedido',
#   'eliminado',
#   'error'],
#  ['status', 'apelacion', 'sé', 'número', 'seguimiento'],
#  ['podria', 'ayudarme', 'persona', 'pueda', 'ayudarme'],
#  ['qué',
#   'muestra',
#   'pedido',
#   'qué',
#   'pedido',
#   'sigue',
#   'cerrando',
#   'después',
#   'pago'],
#  ['devolví',
#   'producto',
#   'recibido',
#   'reemplazo',
#   'reembolso',
#   'cómo',
#   'recibo',
#   'reembolso',
#   'devolví',
#   'producto'],
#  ['hola', 'refleja', 'pago', 'qué', 'pago', 'verificado'],
#  ['buenos', 'días', 'vendedor', 'pedido', 'envío', 'días', 'tiempo'],
#  ['buenos', 'días', 'cuántos', 'días', 'compra', 'llegue', 'país'],
#  ['podido',
#   'pagar',
#   'tarjeta',
#   'debo',
#   'hacer',
#   'alguna',
#   'manera',
#   'pueda',
#   'hacer',
#   'pedido',
#   'pagar',
#   'él',
#   'usando',
#   'tarjeta',
#   'crédito'],
#  ['vendedor',
#   'responde',
#   'qué',
#   'debo',
#   'hacer',
#   'vendedor',
#   'responde',
#   'disputa',
#   'qué',
#   'puedo',
#   'hacer'],
#  ['qué',
#   'aparece',
#   'pagado',
#   'pago',
#   'sido',
#   'deducido',
#   'tarjeta',
#   'sitio',
#   'web',
#   'dice',
#   'pedido',
#   'sido',
#   'entregado',
#   'recibido'],
#  ['hago', 'cómo', 'hago', 'pedido', 'envíe', 'rápidamente'],
#  ['si',
#   'hicieras',
#   'caso',
#   'dejarás',
#   'enviar',
#   'preguntas',
#   'tal',
#   'vez',
#   'entenderías',
#   'preguntas',
#   'respuestas'],
#  ['entonces',
#   'qué',
#   'haces',
#   'entonces',
#   'si',
#   'puedes',
#   'contactar',
#   'vendedor'],
#  ['cómo',
#   'encuentro',
#   'producto',
#   'cómo',
#   'encuentro',
#   'compras',
#   'anteriores'],
#  ['qué',
#   'protección',
#   'comprador',
#   'cómo',
#   'comprobar',
#   'fecha',
#   'límite',
#   'protección',
#   'comprador'],
#  ['cómo',
#   'puedo',
#   'pagar',
#   'pedidos',
#   'sólo',
#   'pago',
#   'cómo',
#   'puedo',
#   'ver',
#   'pedidos'],
#  ['qué',
#   'pasará',
#   'después',
#   'abrir',
#   'disputa',
#   'qué',
#   'pasará',
#   'después',
#   'dejar',
#   'valoración'],
#  ['buen',
#   'día',
#   'dando',
#   'seguimiento',
#   'solicitud',
#   'hace',
#   'varios',
#   'dias',
#   'vendedor',
#   'responde',
#   'vendedor',
#   'responde',
#   'petición',
#   'reembolso'],
#  ['sistema',
#   'deja',
#   'pagar',
#   'qué',
#   'sistema',
#   'dice',
#   'puedo',
#   'participar',
#   'promoción'],
#  ['puedo',
#   'hacer',
#   'salvar',
#   'pedidos',
#   'si',
#   'dirección',
#   'viene',
#   'incompleta',
#   'puedo',
#   'iniciar',
#   'sesión',
#   'ver',
#   'pedidos'],
#  ['cómo',
#   'puedo',
#   'recibir',
#   'reembolso',
#   'cómo',
#   'puedo',
#   'recibir',
#   'reembolso',
#   'si',
#   'tarjeta',
#   'caducado'],
#  ['reembolso', 'quiero', 'pedir', 'reembolso'],
#  ['qué',
#   'aparece',
#   'pagado',
#   'pago',
#   'sido',
#   'deducido',
#   'tarjeta',
#   'qué',
#   'pedido',
#   'sido',
#   'pagado',
#   'doblemente'],
#  ['qué',
#   'aparece',
#   'pagado',
#   'pago',
#   'sido',
#   'deducido',
#   'tarjeta',
#   'qué',
#   'pago',
#   'sido',
#   'cobrado',
#   'transacción'],
#  ['puedo',
#   'pagar',
#   'mediante',
#   'mercado',
#   'pago',
#   'qué',
#   'puedo',
#   'pagar',
#   'mercado',
#   'pago'],
#  ['cómo', 'hago', 'pedido', 'cómo', 'hago', 'pago', 'adicional', 'pedido'],
#  ['abrí',
#   'disputa',
#   'qué',
#   'debo',
#   'hacer',
#   'continuación',
#   'abrí',
#   'disputa',
#   'vendedor',
#   'rechazó',
#   'quedó',
#   'dinero'],
#  ['problemas', 'pagar', 'problemas', 'iniciar', 'sesión'],
#  ['busco', 'productos', 'cómo', 'busco', 'producto'],
#  ['cuándo',
#   'recibiré',
#   'reembolso',
#   'pedidos',
#   'cancelados',
#   'cuándo',
#   'recibiré',
#   'dinero',
#   'artículos',
#   'cancelados'],
#  ['qué',
#   'puedo',
#   'usar',
#   'cupón',
#   'selección',
#   'qué',
#   'puedo',
#   'usar',
#   'cupón',
#   'vendedor'],
#  ['cuándo', 'devolverá', 'dinero', 'cuándo', 'actualiza', 'tipo', 'cambio'],
#  ['cómo',
#   'usar',
#   'cupón',
#   'pedido',
#   'cupón',
#   'cómo',
#   'uso',
#   'nuevo',
#   'pedido'],
#  ['qué', 'congelado', 'pedido', 'qué', 'pedido', 'congelado'],
#  ['cuenta', 'congelada', 'cómo', 'cierro', 'cuenta'],
#  ['aduana', 'pagar', 'tasas', 'aduana', 'eeuu'],
#  ['qué',
#   'pagado',
#   'pedidos',
#   'embargo',
#   'descontado',
#   'dinero',
#   'cuenta',
#   'qué',
#   'cobrado',
#   'dos',
#   'veces',
#   'cuenta'],
#  ['abrir',
#   'disputa',
#   'sale',
#   'cuenta',
#   'suspendida',
#   'puedo',
#   'cambiar',
#   'apellido',
#   'cuenta'],
#  ['vendedor',
#   'realizado',
#   'reembolso',
#   'reenviado',
#   'pedido',
#   'intentado',
#   'ponerme',
#   'contacto',
#   'él',
#   'ignora',
#   'intentado',
#   'hacer',
#   'seguimiento',
#   'envío',
#   'número',
#   'través',
#   'ems',
#   'sale'],
#  ['número',
#   'pedido',
#   'igual',
#   'número',
#   'cuenta',
#   'escribo',
#   'número',
#   'cuenta',
#   'formulario',
#   'western',
#   'union'],
#  ['quiero', 'quiero', 'buscar', 'producto'],
#  ['qué',
#   'pago',
#   'sido',
#   'deducido',
#   'dos',
#   'veces',
#   'qué',
#   'cobró',
#   'dos',
#   'veces'],
# ...
#  ['cómo',
#   'utilizo',
#   'servicio',
#   'garantía',
#   'año',
#   'cómo',
#   'uso',
#   'servicio',
#   'protección',
#   'comprador'],
#  ['cuánto',
#   'tiempo',
#   'tarda',
#   'obtener',
#   'reembolso',
#   'completo',
#   'cuánto',
#   'tarda',
#   'tiempo',
#   'procesamiento'],
#  ['maquina', 'necesito', 'factura', 'pedido', 'realizado'],
#  ['qué',
#   'tarda',
#   'pago',
#   'procese',
#   'qué',
#   'cerró',
#   'después',
#   'hiciera',
#   'pago'],
#  ['cómo',
#   'puedo',
#   'ganar',
#   'puntos',
#   'conseguir',
#   'cupones',
#   'cómo',
#   'puedo',
#   'hacer',
#   'pago',
#   'cupones'],
#  ['qué',
#   'podido',
#   'procesar',
#   'pago',
#   'razones',
#   'seguridad',
#   'qué',
#   'cierran',
#   'pedido',
#   'razones',
#   'seguridad'],
#  ['así', 'ayer', 'qué', 'ciudad', 'envían'],
#  ['reembolso', 'qué', 'reembolso', 'rápido'],
#  ['producto',
#   'recibido',
#   'bueno',
#   'funciona',
#   'qué',
#   'puedo',
#   'hacer',
#   'recibido',
#   'reembolso',
#   'qué',
#   'puedo',
#   'hacer'],
#  ['qué',
#   'puedo',
#   'encontrar',
#   'pedido',
#   'cuenta',
#   'qué',
#   'puedo',
#   'encontrar',
#   'producto',
#   'tienda'],
#  ['semana',
#   'pasada',
#   'puedo',
#   'comprar',
#   'puedo',
#   'comprar',
#   'directamente',
#   'lista',
#   'deseos'],
#  ['puedo',
#   'usar',
#   'paypal',
#   'hacer',
#   'pago',
#   'puedo',
#   'usar',
#   'paypal',
#   'hacer',
#   'pago'],
#  ['cuándo',
#   'podré',
#   'conseguir',
#   'reembolso',
#   'completo',
#   'cuándo',
#   'reembolso'],
#  ['cómo',
#   'puedo',
#   'utilizar',
#   'cupón',
#   'código',
#   'cupón',
#   'cómo',
#   'puedo',
#   'usar',
#   'cupón',
#   'código',
#   'cupón'],
#  ['correo',
#   'indicó',
#   'dirección',
#   'mal',
#   'están',
#   'devolviendo',
#   'producto',
#   'dirección',
#   'envío',
#   'tenía',
#   'nombre',
#   'mal'],
#  ['alguien', 'conteste', 'favor', 'cargando', 'favor', 'espere'],
#  ['devoluciones',
#   'locales',
#   'quiénes',
#   'proveedores',
#   'pueden',
#   'ofrecer',
#   'dropshipping'],
#  ['hola',
#   'alguien',
#   'alguien',
#   'robado',
#   'tarjeta',
#   'crédito',
#   'qué',
#   'puedo',
#   'hacer'],
#  ['compras', 'llegado', 'periodo', 'finalizado', 'productos', 'llegado'],
#  ['cómo',
#   'hacer',
#   'pago',
#   'través',
#   'boleto',
#   'cómo',
#   'recibo',
#   'rembolso',
#   'través',
#   'boleto'],
#  ['qué',
#   'puedo',
#   'usar',
#   'cupón',
#   'selección',
#   'cómo',
#   'puedo',
#   'usar',
#   'cupón'],
#  ['hice',
#   'proceso',
#   'fecha',
#   'recibido',
#   'producto',
#   'reembolso',
#   'pagué',
#   'pedido',
#   'recibido'],
#  ['ok', 'enviar', 'quiero', 'enviar', 'país'],
#  ['dónde', 'está', 'cupón', 'prometido', 'vi', 'pedido', 'dónde', 'está'],
#  ['sé',
#   'qué',
#   'paquete',
#   'pone',
#   'envío',
#   'cancelado',
#   'qué',
#   'pedido',
#   'pone',
#   'quiere',
#   'apelar'],
#  ['vendedor',
#   'respondió',
#   'pedido',
#   'nunca',
#   'llegó',
#   'hice',
#   'compra',
#   'respondió'],
#  ['alguien', 'productos', 'llegaron', 'ciudad', 'alguien', 'quedó'],
#  ['si', 'claro', 'si', 'cancelo', 'pedido', 'necesito', 'dinero', 'verdad'],
#  ['qué', 'puedo', 'realizar', 'pedido', 'qué', 'puedo', 'canjear', 'cupón'],
#  ['qué',
#   'sale',
#   'error',
#   'intentar',
#   'pagar',
#   'qué',
#   'sigo',
#   'recibiendo',
#   'error',
#   'intento',
#   'pagar',
#   'cosas'],
#  ['entonces', 'humano', 'persona'],
#  ['qué', 'pago', 'realizado', 'qué', 'publicado', 'valoración'],
#  ['quiero', 'reembolso', 'quiero', 'cancelar', 'pedido'],
#  ['qué', 'pago', 'realizado', 'qué', 'fallado', 'pago'],
#  ['hola',
#   'buenos',
#   'días',
#   'hice',
#   'compra',
#   'llegó',
#   'plazo',
#   'tiempo',
#   'viaje',
#   'pude',
#   'verla',
#   'regresé',
#   'casa',
#   'había',
#   'pasado',
#   'plazo',
#   'abrir',
#   'disputa',
#   'plazo',
#   'confirmación',
#   'expirado'],
#  ['alguien', 'conteste', 'favor', 'favor', 'incluya', 'factura'],
#  ['cómo',
#   'puedo',
#   'combinar',
#   'varios',
#   'pedidos',
#   'solo',
#   'pago',
#   'cómo',
#   'puedo',
#   'pagar',
#   'productos',
#   'cesta',
#   'compra',
#   'solo',
#   'pago'],
#  ['problema', 'apelacion', 'puedo', 'enviar', 'problema', 'pedido'],
#  ['cómo',
#   'editar',
#   'cuenta',
#   'puedo',
#   'editar',
#   'dirección',
#   'facturación',
#   'xxx'],
#  ['puedo',
#   'realizar',
#   'pago',
#   'puedo',
#   'asegurarme',
#   'pago',
#   'cliente',
#   'seguro'],
#  ['chat',
#   'online',
#   'quiero',
#   'comprar',
#   'productos',
#   'revenderlos',
#   'tienda',
#   'online'],
#  ['email', 'puedo', 'cambiar', 'email'],
#  ['qué',
#   'puedo',
#   'dejar',
#   'comentarios',
#   'pedido',
#   'qué',
#   'puedo',
#   'enviar',
#   'petición',
#   'garantía',
#   'pedido'],
#  ['cómo',
#   'puedo',
#   'comprobar',
#   'si',
#   'dirección',
#   'entrega',
#   'correcta',
#   'cómo',
#   'puedo',
#   'comprobar',
#   'si',
#   'dirección',
#   'correcta',
#   'envío'],
#  ['proveedor', 'contesta', 'proveedor', 'enviado', 'pedido'],
#  ['cómo',
#   'puedo',
#   'pagar',
#   'moneda',
#   'local',
#   'cómo',
#   'puedo',
#   'pagar',
#   'pedidos',
#   'solo',
#   'pago'],
#  ['hice', 'compra', 'hice', 'compra', 'respondió'],
#  ['abrí',
#   'disputa',
#   'qué',
#   'debo',
#   'hacer',
#   'continuación',
#   'abrí',
#   'disputa',
#   'obtuve',
#   'respuesta',
#   'vendedor'],
#  ['qué',
#   'pasará',
#   'después',
#   'abrir',
#   'disputa',
#   'qué',
#   'pasará',
#   'después',
#   'escalar',
#   'disputa'],
#  ['si', 'pasa', 'tiempo', 'llegado', 'ahora', 'pedido', 'llegado'],
#  ['producto',
#   'compré',
#   'defectuoso',
#   'qué',
#   'debo',
#   'hacer',
#   'producto',
#   'recibido',
#   'bueno',
#   'funciona',
#   'qué',
#   'puedo',
#   'hacer'],
#  ['nombre',
#   'contraseña',
#   'cuenta',
#   'incorrecto',
#   'reembolso',
#   'pedido',
#   'incorrecto'],
#  ['qué',
#   'pago',
#   'está',
#   'deducido',
#   'incorrectamente',
#   'qué',
#   'está',
#   'vacía',
#   'cesta'],
#  ['puedo',
#   'pagar',
#   'mediante',
#   'mercado',
#   'pago',
#   'puedo',
#   'enviar',
#   'cheque',
#   'método',
#   'pago'],
#  ['vendedor',
#   'responde',
#   'solicitud',
#   'reembolso',
#   'qué',
#   'pasará',
#   'si',
#   'vendedor',
#   'responde',
#   'disputa'],
#  ['chat', 'linea', 'cuánto', 'tardan', 'reembolsar'],
#  ['producto',
#   'recibido',
#   'bueno',
#   'funciona',
#   'qué',
#   'puedo',
#   'hacer',
#   'producto',
#   'bueno',
#   'puedo',
#   'contactar',
#   'vendedor'],
#  ['cómo', 'hago', 'pago', 'paypal', 'cómo', 'hago', 'pedido'],
#  ['cómo', 'puedo', 'pagar', 'webmoney', 'cómo', 'pagar', 'través', 'webmoney'],
#  ['pendiente',
#   'devolucion',
#   'producto',
#   'devolucion',
#   'importe',
#   'producto',
#   'pendiente',
#   'recibir'],
#  ['cuándo',
#   'puedo',
#   'recibir',
#   'reembolso',
#   'cómo',
#   'puedo',
#   'recibir',
#   'reembolso',
#   'si',
#   'tarjeta',
#   'existe'],
#  ['pedido',
#   'finalizado',
#   'cómo',
#   'dejar',
#   'comentario',
#   'pedido',
#   'finalizado',
#   'disputa'],
#  ['problema',
#   'apelacion',
#   'puedo',
#   'enviar',
#   'problema',
#   'corrigiendo',
#   'dirección',
#   'envío'],
#  ['qué',
#   'pago',
#   'sido',
#   'deducido',
#   'dos',
#   'veces',
#   'qué',
#   'pago',
#   'sido',
#   'cobrado',
#   'dos',
#   'veces'],
#  ['producto',
#   'bueno',
#   'puedo',
#   'ponerme',
#   'contacto',
#   'vendedor',
#   'producto',
#   'original'],
#  ['qué', 'pasará', 'después', 'abrir', 'disputa', 'capaz', 'abrir', 'disputa'],
#  ['vendedor',
#   'cancelado',
#   'pedido',
#   'error',
#   'producto',
#   'está',
#   'enviado',
#   'recibo',
#   'devolución',
#   'dinero',
#   'qué',
#   'hago',
#   'qué',
#   'pasa',
#   'si',
#   'tiempo',
#   'acaba',
#   'vendedor',
#   'enviado',
#   'pedido'],
#  ['entonces',
#   'puedo',
#   'hacer',
#   'salvar',
#   'pedidos',
#   'si',
#   'dirección',
#   'viene',
#   'incompleta',
#   'qué',
#   'puedo',
#   'hacer',
#   'si',
#   'proveedor',
#   'usa',
#   'imágenes',
#   'permiso'],
#  ['hola',
#   'buenos',
#   'dias',
#   'aquí',
#   'sigo',
#   'esperando',
#   'gift',
#   'card',
#   'movil',
#   'abrí',
#   'disputa',
#   'hace',
#   'mes',
#   'aún',
#   'esperando',
#   'respuesta'],
#  ['vendedor',
#   'fraude',
#   'cómo',
#   'puedo',
#   'informar',
#   'cuál',
#   'símbolo',
#   'vendedor',
#   'verificado'],
#  ['puedo',
#   'abrir',
#   'disputa',
#   'puedo',
#   'abrir',
#   'disputa',
#   'necesito',
#   'ayuda'],
#  ['disputa', 'disputa', 'rechazada'],
#  ['puedo',
#   'abrir',
#   'disputa',
#   'finalice',
#   'periodo',
#   'proteccion',
#   'temporizador',
#   'tiempo',
#   'restante',
#   'disputa',
#   'parece',
#   'extraño'],
#  ['pedido', 'cancelado', 'qué', 'pedido', 'cancelado'],
#  ['puedo', 'pagarlo', 'puedo', 'cambiar', 'pedido', 'despues', 'pagarlo'],
#  ['dime', 'respuesta', 'eva', 'qué', 'esperando', 'respuesta', 'parte'],
#  ['cómo', 'seguimiento', 'producto', 'paypal', 'método', 'pago'],
#  ['pedido',
#   'lleva',
#   'dos',
#   'semanas',
#   'aerolínea',
#   'pedido',
#   'está',
#   'aduana'],
#  ['lees', 'cobraron', 'más', 'dinero'],
#  ['puedo',
#   'cambiar',
#   'envío',
#   'gratis',
#   'quiero',
#   'cambiar',
#   'envío',
#   'envío',
#   'gratuito'],
#  ['deseo', 'comunicarme', 'supervisor', 'quiero', 'producto', 'descuento'],
#  ['cómo', 'eliminar', 'cupones', 'cómo', 'añado', 'cupones', 'pedido'],
#  ['vendedor',
#   'contesta',
#   'respecto',
#   'pedido',
#   'vendedor',
#   'contesta',
#   'mensajes'],
#  ['cómo',
#   'puedo',
#   'saber',
#   'si',
#   'pedido',
#   'sido',
#   'cancelado',
#   'recibido',
#   'reembolso',
#   'pedido',
#   'sido',
#   'cancelado'],
#  ['puedo',
#   'cambiar',
#   'detalles',
#   'pedido',
#   'tamaño',
#   'envío',
#   'etc',
#   'cómo',
#   'puedo',
#   'conocer',
#   'detalles',
#   'producto'],
#  ['dice',
#   'sistema',
#   'ocupado',
#   'pedido',
#   'cerrado',
#   'sistema',
#   'debido',
#   'vendedor',
#   'sospechoso'],
#  ['cómo',
#   'cancelo',
#   'pedido',
#   'recibiré',
#   'reembolso',
#   'si',
#   'cancelo',
#   'pedido'],
#  ['sale', 'pedidos', 'eliminados', 'pedidos', 'parados', 'aduanas'],
#  ['deja', 'identificarme', 'deja', 'proceder', 'pedido'],
#  ['qué',
#   'hago',
#   'vendedor',
#   'deje',
#   'enviarme',
#   'mensajes',
#   'qué',
#   'hacer',
#   'vendedor',
#   'responde',
#   'emails'],
#  ['cuándo',
#   'puedo',
#   'recibir',
#   'reembolso',
#   'cuánto',
#   'tiempo',
#   'puedo',
#   'recibir',
#   'reembolso'],
#  ['cómo', 'cancelo', 'pedido', 'cómo', 'cancelo', 'pedido', 'si', 'pagado'],
#  ['qué',
#   'cargo',
#   'tarjeta',
#   'crédito',
#   'tenía',
#   'pedido',
#   'quiero',
#   'saber',
#   'qué',
#   'cargo',
#   'tarjeta',
#   'crédito',
#   'recibir',
#   'pedidos'],
#  ['realice', 'compra', 'contacto', 'vendedor', 'quiero', 'cancelar', 'compra'],
#  ['pedido',
#   'sido',
#   'cancelado',
#   'qué',
#   'pedido',
#   'sido',
#   'cancelado',
#   'pago',
#   'hecho'],
#  ['agente', 'necesito', 'hablar', 'agente'],
#  ['ahora',
#   'ofrece',
#   'enviarme',
#   'vez',
#   'producto',
#   'si',
#   'cancelo',
#   'disputa',
#   'si',
#   'cierro',
#   'disputa',
#   'puedo',
#   'reabrirla',
#   'vez'],
#  ['llega', 'pedido', 'pedido', 'llegó', 'color', 'difiere', 'pedí'],
#  ['pagar',
#   'tasas',
#   'aduanas',
#   'importación',
#   'cuánto',
#   'necesito',
#   'pagar',
#   'impuestos',
#   'tasas',
#   'aduanas'],
#  ['producto',
#   'está',
#   'roto',
#   'quiero',
#   'pedir',
#   'producto',
#   'proveedor',
#   'está',
#   'bloqueado',
#   'qué'],
#  ['vendedor', 'cancelado', 'envio', 'vendedor', 'enviado', 'artículo'],
#  ['cómo',
#   'utilizo',
#   'servicio',
#   'garantía',
#   'año',
#   'cómo',
#   'puedo',
#   'dejar',
#   'valoración',
#   'servicio',
#   'garantía'],
#  ['puedo',
#   'recibir',
#   'reembolso',
#   'mediante',
#   'western',
#   'union',
#   'qué',
#   'puedo',
#   'pagar',
#   'western',
#   'union'],
#  ['cómo', 'recuperar', 'cupón', 'cómo', 'obtener', 'cupón'],
#  ['momento', 'vendedor', 'envió', 'pedido'],
#  ['vendedor',
#   'dice',
#   'stock',
#   'pide',
#   'cancele',
#   'vendedor',
#   'stock',
#   'artículo'],
#  ['vendedor',
#   'respondió',
#   'pedido',
#   'nunca',
#   'llegó',
#   'vendedor',
#   'nunca',
#   'envió',
#   'pedido'],
#  ['hola', 'hola'],
#  ['bien', 'disputas', 'lentas'],
#  ['hice',
#   'pedido',
#   'varios',
#   'items',
#   'estan',
#   'enviando',
#   'separado',
#   'hacer',
#   'envie',
#   'pedido',
#   'paquete',
#   'cómo',
#   'puedo',
#   'hacer',
#   'múltiples',
#   'pedidos',
#   'mismo',
#   'vendedor',
#   'envíe',
#   'junto'],
#  ['cuenta',
#   'desactivada',
#   'sentimos',
#   'está',
#   'autorizado',
#   'iniciar',
#   'sesión',
#   'cuenta'],
#  ['saber',
#   'nombre',
#   'telefono',
#   'persona',
#   'encargada',
#   'entrega',
#   'producto',
#   'nombre',
#   'calle',
#   'está',
#   'mal',
#   'qué',
#   'puedo',
#   'hacer'],
#  ['recibido',
#   'reembolso',
#   'recibido',
#   'artículo',
#   'cómo',
#   'pido',
#   'reembolso'],
#  ['cómo', 'hago', 'pedido', 'cómo', 'hago', 'seguimiento', 'pedido'],
#  ['cómo', 'cancelo', 'pedido', 'cómo', 'cancelo', 'pedido'],
#  ['podria',
#   'ayudarme',
#   'pueden',
#   'ayudarme',
#   'hacer',
#   'seguimiento',
#   'pedido'],
#  ['pedido', 'nunca', 'volveré', 'hacer', 'pedido', 'compañía'],
#  ['cuantos',
#   'dias',
#   'hacer',
#   'pago',
#   'artículos',
#   'diferentes',
#   'proveedores',
#   'quiero',
#   'hacer',
#   'solo',
#   'pago'],
#  ['voy', 'denunciar', 'cómo', 'denunciar', 'vulneración', 'marca'],
#  ['página',
#   'pago',
#   'aparecen',
#   'opciones',
#   'pago',
#   'transferencia',
#   'bancaria',
#   'western',
#   'union',
#   'hecho',
#   'pago',
#   'transferencia',
#   'bancaria',
#   'qué',
#   'aún',
#   'pone',
#   'pendiente',
#   'pago'],
#  ['aun',
#   'así',
#   'gustaría',
#   'comprar',
#   'pedido',
#   'gustaría',
#   'saber',
#   'qué',
#   'pedido',
#   'cancelado'],
#  ['favor', 'ajude', 'podrían', 'llamar', 'favor'],
#  ['respuesta',
#   'anterior',
#   'comprendo',
#   'dónde',
#   'está',
#   'respuesta',
#   'proveedor'],
#  ['hice',
#   'pagos',
#   'refleja',
#   'hice',
#   'pedido',
#   'vendedor',
#   'pidió',
#   'cancelarlo'],
#  ['cómo',
#   'puedo',
#   'saber',
#   'id',
#   'usuario',
#   'cómo',
#   'mantengo',
#   'nivel',
#   'usuario'],
#  ['dónde', 'puedo', 'reclamar', 'quiero', 'reclamar'],
#  ['llegado',
#   'pedido',
#   'quiero',
#   'restablecer',
#   'contraseña',
#   'llegado',
#   'email'],
#  ['vale', 'van', 'mas', 'mes', 'van', 'dar', 'información', 'envío'],
#  ['cuándo', 'llegará', 'pedido', 'cuándo', 'recibo', 'pedido'],
#  ['cupón', 'cómo', 'obtengo', 'cupón'],
#  ['necesito',
#   'hacer',
#   'devolucion',
#   'necesito',
#   'hacer',
#   'compra',
#   'rápida',
#   'urgente'],
#  ['problemas',
#   'siguientes',
#   'pedidos',
#   'problemas',
#   'app',
#   'chatear',
#   'persona'],
#  ['quiero', 'hablar', 'robot', 'quiero', 'conectarme', 'robot'],
#  ['cuándo',
#   'recibiré',
#   'reembolso',
#   'si',
#   'pago',
#   'tarjeta',
#   'crédito',
#   'cuándo',
#   'recibiré',
#   'reembolso'],
#  ['buenas', 'tardes', 'hola', 'tal', 'buenas', 'noches'],
#  ['nombre',
#   'contraseña',
#   'cuenta',
#   'incorrecto',
#   'nombre',
#   'cuenta',
#   'contraseña',
#   'incorrecta'],
#  ['qué',
#   'tarda',
#   'pago',
#   'procese',
#   'qué',
#   'pedido',
#   'sigue',
#   'cerrando',
#   'después',
#   'pago'],
#  ['calificar', 'pedido', 'vendedor', 'respeta', 'pedido'],
#  ['después',
#   'cancelación',
#   'cuántos',
#   'días',
#   'devolverán',
#   'dinero',
#   'cuántos',
#   'días',
#   'recibiré',
#   'pedido'],
#  ['apelacion', 'página', 'real'],
#  ['qué', 'pago', 'realizado', 'qué', 'valoración', 'mostrado'],
#  ['hola', 'eva', 'hola', 'tal'],
#  ['qué',
#   'está',
#   'disponible',
#   'cuenta',
#   'qué',
#   'envío',
#   'gratis',
#   'está',
#   'disponible',
#   'país'],
#  ['vendedor',
#   'realizado',
#   'reembolso',
#   'reenviado',
#   'pedido',
#   'intentado',
#   'ponerme',
#   'contacto',
#   'él',
#   'ignora',
#   'vendedor',
#   'responsable',
#   'ignora'],
#  ['cómo',
#   'elimino',
#   'dirección',
#   'email',
#   'lista',
#   'correo',
#   'cómo',
#   'verifico',
#   'dirección',
#   'email'],
#  ['cuándo',
#   'recibiré',
#   'reembolso',
#   'si',
#   'pago',
#   'tarjeta',
#   'crédito',
#   'cuándo',
#   'recibiré',
#   'reembolso',
#   'si',
#   'pago',
#   'tarjeta',
#   'crédito'],
#  ['cómo',
#   'puedo',
#   'recibir',
#   'reembolso',
#   'cómo',
#   'puedo',
#   'recibir',
#   'reembolso'],
#  ['cuándo',
#   'recibiré',
#   'reembolso',
#   'si',
#   'pago',
#   'tarjeta',
#   'crédito',
#   'cuándo',
#   'recibiré',
#   'reembolso',
#   'si',
#   'pagué',
#   'webmoney'],
#  ['necesito',
#   'reimprimir',
#   'ticket',
#   'oxxo',
#   'hacer',
#   'pago',
#   'efectivo',
#   'qué',
#   'página',
#   'puedo',
#   'hacer',
#   'seguimiento',
#   'paquete'],
#  ['devoluciones',
#   'locales',
#   'tasas',
#   'pagamos',
#   'demasiado',
#   'altas',
#   'importar',
#   'productos',
#   'página'],
#  ['devuelto',
#   'origen',
#   'cómo',
#   'puedo',
#   'consultar',
#   'cuánto',
#   'dinero',
#   'sido',
#   'devuelto'],
#  ['cómo',
#   'puedo',
#   'cambiar',
#   'términos',
#   'disputa',
#   'cómo',
#   'puedo',
#   'cambiar',
#   'dirección',
#   'recepción'],
#  ['código',
#   'verificación',
#   'funciona',
#   'código',
#   'verificación',
#   'está',
#   'mal'],
#  ['qué',
#   'cancelaron',
#   'pedido',
#   'qué',
#   'pedido',
#   'está',
#   'cerrado',
#   'pedido',
#   'rechazado'],
#  ['cuenta', 'bloqueada', 'puedo', 'acceder', 'cuenta'],
#  ['error',
#   'indicando',
#   'debo',
#   'hacer',
#   'apelacion',
#   'intentando',
#   'hacer',
#   'pedido',
#   'siempre',
#   'dice',
#   'error'],
#  ['abrir', 'disputa', 'consigo', 'abrir', 'disputa'],
#  ...]
