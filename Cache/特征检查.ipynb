# %%
import pickle

# %%
with open('token_test_a.pkl', 'rb') as pkl:
    test_token_a_left, test_token_a_right = pickle.load(pkl)

# %%
for i in range(500):
    print(test_token_a_left[i], test_token_a_right[i])
# Out:
# ['cómo', 'poder', 'recibir', 'un', 'reembolso', 'mediante', 'tarjeta'] ['¿', 'cómo', 'poder', 'recibir', 'un', 'reembolso']
# ['cómo', 'poder', 'recibir', 'un', 'reembolso', 'mediante', 'tarjeta'] ['¿', 'cómo', 'poder', 'recibir', 'un', 'reembolso', 'si', 'mi', 'banco', 'har', 'ir', 'a', 'bancarrota']
# ['no', 'her', 'poder', 'pagar', 'con', 'mi', 'tarjeta', 'que', 'deber', 'hacer'] ['no', 'poder', 'pagar', 'con', 'mi', 'tarjeta', 'de', 'débito', '¿', 'qué', 'poder', 'hacer']
# ['no', 'her', 'poder', 'pagar', 'con', 'mi', 'tarjeta', 'que', 'deber', 'hacer'] ['no', 'poder', 'pagar', 'mi', 'pedido', 'con', 'tarjeta', 'visar', 'de', 'débito', '¿', 'qué', 'poder', 'hacer']
# ['no', 'her', 'poder', 'pagar', 'con', 'mi', 'tarjeta', 'que', 'deber', 'hacer'] ['no', 'poder', 'pagar', 'con', 'tarjeta']
# ...

# %%
with open('test_b_replace_token.pkl', 'rb') as pkl:
    test_token_left_b, test_token_right_b = pickle.load(pkl)

# %%
for i in range(500):
    print(i+1, test_token_left_b[i], test_token_right_b[i])
# Out:
# 1 ['aceptar', 'tarjeta', 'virtual'] ['¿', 'aceptar', 'tarjeta', 'visar', 'prepago', 'de', 'walmart']
# 2 ['deseo', 'que', 'mi', 'pedido', 'se', 'enviar', 'a', 'un', 'dirección', 'diferente'] ['me', 'gustar', 'que', 'mis', 'producto', 'se', 'enviar', 'a', 'un', 'nuevo', 'dirección']
# 3 ['que', 'no', 'entiendes'] ['¿', 'por', 'qué', 'no', 'poder', 'pedirlos', 'junto']
# 4 ['cuando', 'ingreso', 'el', 'dato', 'me', 'pedir', 'que', 'colocar', 'el', 'nombre', 'en', 'ingl', 'pero', 'lo', 'hacer', 'y', 'me', 'seguir', 'decir', 'lo', 'mismo'] ['el', 'vendedor', 'no', 'tener', 'el', 'zapato', 'que', 'pedí', 'pero', 'no', 'me', 'contestar']
# 5 ['bueno', 'dia', 'no', 'her', 'recibir', 'un', 'producto', 'que', 'comprar', 'hacer', 'casi', 'cuatro', 'més', 'el', 'vendedor', 'cancelo', 'el', 'pedido', 'y', 'decir', 'que', 'me', 'lo', 'volvia', 'a', 'reenviar'] ['necesitar', 'cancelar', 'un', 'pedido', 'pero', 'el', 'vendedor', 'aún', 'no', 'lo', 'cancelar']
# ...

# %%
with open('Es2IndexDic.pkl', 'rb') as pkl:
    es_dic = pickle.load(pkl)

# %%
len(es_dic)
# Out:
# 5841

# %%
with open('test_b_index.pkl', 'rb') as pkl:
    test_b_index_left, test_b_index_right = pickle.load(pkl)

# %%
for i in range(500):
    print(test_b_index_left[i], test_b_index_right[i])
# Out:
# [1197, 175, 3044] [32, 1197, 175, 517, 1711, 18, 2642]
# [714, 28, 37, 48, 29, 133, 45, 12, 326, 54] [235, 236, 28, 111, 9, 29, 133, 45, 12, 195, 326]
# [28, 14, 918] [32, 92, 101, 14, 70, 4326, 900]
# [360, 556, 8, 549, 235, 681, 28, 460, 8, 454, 7, 516, 51, 65, 5, 13, 235, 376, 27, 65, 377] [8, 114, 14, 119, 8, 253, 28, 56, 51, 14, 235, 2599]
# [436, 2073, 14, 15, 10, 12, 9, 28, 117, 5, 1561, 364, 41, 8, 114, 280, 8, 48, 13, 27, 28, 235, 65, 3947, 45, 1915] [88, 220, 12, 48, 51, 8, 114, 541, 14, 65, 220]
# [61, 676, 8, 371, 191, 8, 52] [32, 61, 519, 8, 1452, 191, 8, 52]
# [8, 48, 14, 50, 8, 717, 3, 3087] [14, 99, 8, 48]
# [119, 12, 160, 135, 12, 114] [119, 12, 160, 135, 12, 1884]
# [130, 5, 1561, 589, 26, 117, 12, 934, 13, 842, 14, 50] [99, 220, 8, 48, 51, 842, 467, 8, 114, 65, 133]
# [61, 70, 10, 12, 31, 191, 202, 45, 649, 18, 650] [32, 61, 407, 12, 2579, 45, 649, 18, 650]
# ...

# %%
with open('es_unk_words.pkl', 'rb') as pkl:
    es_unk_words = pickle.load(pkl)

# %%
es_unk_words
# Out:
# ['publicándome',
#  'shopify',
#  'transcurrer',
#  '12:05',
#  'dormiste',
#  'd0',
#  'hagamelar',
#  'divertidar',
#  'ignorándome',
#  'livechat',
#  'resurger',
#  'dingding',
#  'dármelo',
#  'esterlino',
#  'giropay',
#  'neteller',
#  'norteamérico',
#  'mensaje:hola',
#  'hubieser',
#  'métanme',
#  'rechasado',
#  'negasteis',
#  'mezcláis',
#  'moneycard',
#  'valuations',
#  'algunospedidos',
#  'haynada',
#  'suspirio',
#  'estuvieser',
#  'huyyy',
#  'dichomovil',
#  'hallegado',
#  'infringer',
#  'bórrenme',
#  'aliezpress',
#  'incumpler',
#  'inclumplio',
#  'pqagima',
#  'sustraido',
#  'chingadera',
#  'disponéis',
#  'querendar',
#  'reshipped',
#  'simcard',
#  'liberasteis',
#  'mercadopago',
#  'reañlizo',
#  'ipay_rs',
#  'peiomi',
#  'mirmira',
#  'certicado',
#  'notoficaréis',
#  'digitacion',
#  'colaborenme',
#  'estapagina',
#  'acaboel',
#  's8',
#  'quedebo',
#  'interpuse',
#  'perrnosa',
#  'miranndo',
#  'inlges',
#  'vuestrapagina',
# ...

# %%
len(es_unk_words)
# Out:
# 220
